# %% [markdown]
# <a href="https://colab.research.google.com/github/Marketing-AI/Recommendation-Application/blob/main/mai_predict.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Import libraries

import random
import math
import numpy as np
import pandas as pd
from scipy.stats.stats import pearsonr
import matplotlib.pyplot as plt
from collections import deque

import keras

# %% [markdown]
# # 1. Load Data

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# Load Movies
movies = pd.read_excel('/content/drive/MyDrive/Studium/MAI/Data/movies.xlsx')
movies.head()
# Out:
#    movieId  ...                                       genres
# 0        1  ...  Adventure,Animation,Children,Comedy,Fantasy
# 1        2  ...                   Adventure,Children,Fantasy
# 2        3  ...                               Comedy,Romance
# 3        4  ...                         Comedy,Drama,Romance
# 4        5  ...                                       Comedy
#
# [5 rows x 3 columns]

# %%
# Load Ratings
ratings = pd.read_excel('/content/drive/MyDrive/Studium/MAI/Data/ratings_genres.xlsx')
ratings.head()
# Out:
#    userId  movieId  rating   timestamp                       genres
# 0       1      296     5.0  1147880044  Comedy,Crime,Drama,Thriller
# 1       1      306     3.5  1147868817                        Drama
# 2       1      307     5.0  1147868828                        Drama
# 3       1      665     5.0  1147878820             Comedy,Drama,War
# 4       1      899     3.5  1147868510       Comedy,Musical,Romance

# %%
# Find user with the highest amount of ratings
ratings.userId.mode()
# Out:
# 0    2177
# dtype: int64

# %%
# Provide all possible genres
allGenres = [
               "Adventure",
               "Action",
               "Animation",
               "Children",
               "Comedy",
               "Crime",
               "Documentary",
               "Drama",
               "Fantasy",
               "Film-Noir",
               "Horror",
               "Musical",
               "Mystery",
               "Romance",
               "Sci-Fi",
               "Thriller",
               "War",
               "Western"
]

# %% [markdown]
# # 2. Process Data

# %%
# Initialize data processing methods

def getMoviesByGenre(handle):
  movies[handle] = movies['genres'].str.contains(handle)
  moviesByGenre = movies[movies[handle] == True]
  return moviesByGenre

def getRatingsByGenre(handle):
  ratings[handle] = ratings['genres'].str.contains(handle)
  ratingsByGenre = ratings[ratings[handle] == True]
  return ratingsByGenre

def getGenreMean(handle):
  return ratings.loc[ratings[handle] == True, 'rating'].mean()

def getMaxInList(maxMeans):
  return np.where(maxMeans == np.nanmax(maxMeans))

def identifyMaxGenres(maxMeans, userId):
  result = []
  for index in maxMeans:
    userMax = np.array(np.array(allGenres)[index])
    userMax = np.insert(userMax, 0, userId, axis=0)
    result.append(userMax)
  return result

# %%
# Add genre boolean for each movie

for genre in allGenres:
  getMoviesByGenre(genre)

print("Updated movie columns!")
movies.head()
# Out:
# Updated movie columns!
#    movieId                               title  ...    War Western
# 0        1                    Toy Story (1995)  ...  False   False
# 1        2                      Jumanji (1995)  ...  False   False
# 2        3             Grumpier Old Men (1995)  ...  False   False
# 3        4            Waiting to Exhale (1995)  ...  False   False
# 4        5  Father of the Bride Part II (1995)  ...  False   False
#
# [5 rows x 21 columns]

# %%
ratings['userId'].value_counts()[40:150]
# Out:
# 4060    1376
# 2938    1375
# 2345    1368
# 3128    1364
# 3831    1358
#         ...
# 3847     846
# 859      845
# 3629     845
# 5349     845
# 3778     843
# Name: userId, Length: 110, dtype: int64

# %%
# Add genre boolean for each rating

for genre in allGenres:
  getRatingsByGenre(genre)

print("Updated genre columns!")
ratings.head()
# Out:
# Updated genre columns!
#    userId  movieId  rating   timestamp  ... Sci-Fi Thriller    War Western
# 0       1      296     5.0  1147880044  ...  False     True  False   False
# 1       1      306     3.5  1147868817  ...  False    False  False   False
# 2       1      307     5.0  1147868828  ...  False    False  False   False
# 3       1      665     5.0  1147878820  ...  False    False   True   False
# 4       1      899     3.5  1147868510  ...  False    False  False   False
#
# [5 rows x 23 columns]

# %%
# Create [genre, action] sequence (each pair will be one episode)

## Choose user from dataset
startAt = 3 # User ID
userAmount = 1

userSequencePool = []

for user in range(startAt, startAt + userAmount):
  userRatingSequence = []
  unsortedUserRatings = ratings[ratings['userId'] == user]
  userRatings = unsortedUserRatings.sort_values(by=['timestamp'])

  # Create actions from ratings
  for i, rating in userRatings.iterrows():    
    # Neutral
    observation = [rating['genres'], 0]

    # Positive
    if int(rating['rating']) >= 4.0:
      observation = [rating['genres'], 2]
    
    # Negative
    if int(rating['rating']) <= 2.0:
      observation = [rating['genres'], 1]
    
    userRatingSequence.append(observation)

  userSequencePool.append(userRatingSequence)

print('Number of ratings: %s' % (len(userSequencePool[0])))
print('Example of the appearance of one rating: %s' % userSequencePool[0][0])
# Out:
# Number of ratings: 656
# Example of the appearance of one rating: ['Comedy,Drama,Romance,War', 2]

# %% [markdown]
# # 3. Analyse Data

# %% [markdown]
# ### 3.1 Create Environment

# %%
# Create atrificial environment

class Environment:
  def __init__(self, user, action_space): 

    self.state = np.zeros(action_space)
    self.user = user
  
  # Calculate reward for the given action of an episode
  def episode(self, step, action):  
    correctlyPredicted = False
    currentUser = np.array(userSequencePool)[self.user]

    reward = -0.025
    
    for i, genre in enumerate(allGenres):
      if genre in currentUser[step][0] and i == action:
        correctlyPredicted = True

    if correctlyPredicted:
      # Neutral
      reward = 0.1

      # Positive
      if int(currentUser[step][1]) == 2:
        reward = 0.3

      # Negative
      if int(currentUser[step][1]) == 1:
        reward = -0.2

    return reward, currentUser[step]

  # Simulate the change of the environment
  def update_state(self, currentRating, reward):
    for i, genre in enumerate(allGenres):
      if genre in currentRating:
        self.state[i] += reward

# %% [markdown]
# ### 3.2 Create Agent

# %%
# Create agent

class Agent:
    def __init__(self, action_space, data):
        self.data = data
        self.data_length = len(self.data)
        self.action_space = action_space
        self.action_count = np.zeros(action_space)

        self.epsilon = 0.3
        self.learning_rate = 0.1
        self.discount_factor = 0.01
        self.batch_size = 32

        self.model = self.build_model()
        self.memory = deque(maxlen=100000)
        self.acc = []
        self.loss = []

    # Memorize current episode 
    def remember(self, reward, action, state, next_state, done):
        self.memory.append((state, action, reward, done, next_state))

    # Create model
    def build_model(self):
        model = keras.Sequential()
        model.add(keras.layers.Dense(64, input_shape=(self.action_space,), activation='relu'))
        model.add(keras.layers.Dense(64, activation='relu'))
        model.add(keras.layers.Dense(self.action_space, activation='linear'))
        model.compile(loss='mse', optimizer=keras.optimizers.Adam(lr=self.learning_rate), metrics=keras.metrics.top_k_categorical_accuracy)
        return model

    # Predict action from current state
    def act(self, state):
        # Epsilon greedy for exploration vs. exploitation dilemma
        exploration = (np.random.uniform(0,1) < self.epsilon)
        
        if exploration:
          action = np.random.randint(self.action_space)
        else:
          prediction = self.model.predict(state)
          action = np.argmax(prediction)

        self.action_count[action] += 1
        
        return action

    # Train Neural Network
    def train(self):
        if len(self.memory) < self.batch_size:
          return

        # Create Training Data
        
        ## Get latest episodes to generate training batch
        minibatch = list(self.memory)[-self.batch_size:] 
        states = np.array([i[0] for i in minibatch])
        actions = np.array([i[1] for i in minibatch])
        rewards = np.array([i[2] for i in minibatch])
        next_states = np.array([i[4] for i in minibatch])
        dones = np.array([i[3] for i in minibatch])

        states = np.squeeze(states)
        next_states = np.squeeze(next_states)

        # Q-Algorithm to learn
        targets = np.amax(states) - self.learning_rate * (rewards + self.discount_factor * np.amax(self.model.predict_on_batch(next_states), axis=1) - np.amax(states))
        # Old algorithm: rewards + self.learning_rate*(np.amax(self.model.predict_on_batch(next_states), axis=1))*(1-dones)
        targets_full = self.model.predict_on_batch(states)

        # Map updated q_values to action_space
        ind = np.array([i for i in range(self.batch_size)])
        targets_full[[ind], [actions]] = targets

        # Train model with state and action_space of each memorized episode in batch
        history = self.model.fit(states, targets_full, epochs=1)
        self.loss.append(history.history['loss'][0])
        self.acc.append(history.history['top_k_categorical_accuracy'][0])

# %% [markdown]
# ### 3.3 Run Reinforcement Learning System

# %%
action_space = 18
state_space = 18
user_index = 0

genreRewards = []


# Initialize Environment & Agent
env = Environment(user_index, action_space)
agent = Agent(action_space, userSequencePool[user_index])

for currentRating in range(len(userSequencePool[user_index])):
  isDone = True if currentRating == len(userSequencePool[user_index]) - 1 else False

# # Act
  ## Predict next possible user action
  action = agent.act(np.reshape(env.state, (1, state_space)))
  ## Observe action and generate reward
  reward, currentUser = env.episode(currentRating, action)
  genreRewards.append([action, reward])

# # Update environment
  ## Save current state
  state = env.state
  ## Update the environment with current reward
  env.update_state(currentUser[0], reward)
  ## Save next_state
  next_state = env.state

# # Remember this episode
  agent.remember(reward, action, state, next_state, isDone)

# # Train the neural network
  agent.train()
# Out:
# 1/1 [==============================] - 0s 312ms/step - loss: 0.0059 - top_k_categorical_accuracy: 0.7812
# 1/1 [==============================] - 0s 4ms/step - loss: 0.9958 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0050 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0127 - top_k_categorical_accuracy: 0.1562
# 1/1 [==============================] - 0s 3ms/step - loss: 0.0112 - top_k_categorical_accuracy: 0.1562
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0066 - top_k_categorical_accuracy: 0.1875
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0051 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0245 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 3ms/step - loss: 0.0013 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0043 - top_k_categorical_accuracy: 0.1875
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0068 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0062 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 5ms/step - loss: 0.0050 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 3ms/step - loss: 0.0043 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0036 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 5ms/step - loss: 0.0023 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 5ms/step - loss: 0.0014 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0015 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 4ms/step - loss: 9.5418e-04 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0015 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0016 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0021 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 3ms/step - loss: 0.0018 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 5ms/step - loss: 0.0017 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0016 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0022 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0014 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 7ms/step - loss: 7.5606e-04 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0010 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 6ms/step - loss: 0.0013 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 3ms/step - loss: 5.1985e-04 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 4ms/step - loss: 6.3592e-04 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 4ms/step - loss: 5.9709e-04 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 3ms/step - loss: 6.4020e-04 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0028 - top_k_categorical_accuracy: 0.5312
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0011 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0011 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 6ms/step - loss: 0.0023 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0011 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 4ms/step - loss: 6.7643e-04 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 3ms/step - loss: 8.0268e-04 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 3ms/step - loss: 0.0024 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0023 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0017 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 3ms/step - loss: 0.0025 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 4ms/step - loss: 9.2011e-04 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 4ms/step - loss: 5.8088e-04 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0016 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0018 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0013 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 4ms/step - loss: 6.5716e-04 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 4ms/step - loss: 5.6014e-04 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 7ms/step - loss: 5.9294e-04 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 4ms/step - loss: 6.4184e-04 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 7ms/step - loss: 6.6197e-04 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 4ms/step - loss: 4.4338e-04 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 4ms/step - loss: 2.4424e-04 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 5ms/step - loss: 0.0021 - top_k_categorical_accuracy: 0.4688
# 1/1 [==============================] - 0s 6ms/step - loss: 0.0029 - top_k_categorical_accuracy: 0.5312
# 1/1 [==============================] - 0s 6ms/step - loss: 0.0011 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 3ms/step - loss: 0.0015 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 3ms/step - loss: 0.0019 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 4ms/step - loss: 9.8021e-04 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 7ms/step - loss: 9.5308e-04 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 7ms/step - loss: 0.0012 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 3ms/step - loss: 0.0011 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0094 - top_k_categorical_accuracy: 0.1562
# 1/1 [==============================] - 0s 3ms/step - loss: 0.0038 - top_k_categorical_accuracy: 0.4688
# 1/1 [==============================] - 0s 3ms/step - loss: 0.0044 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 3ms/step - loss: 0.0059 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 3ms/step - loss: 0.0060 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 3ms/step - loss: 0.0059 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 3ms/step - loss: 0.0020 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 6ms/step - loss: 0.0012 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0026 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 3ms/step - loss: 0.0024 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0025 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 6ms/step - loss: 0.0022 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0018 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0015 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0018 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0014 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 5ms/step - loss: 0.0011 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 4ms/step - loss: 9.8937e-04 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 4ms/step - loss: 9.9050e-04 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 3ms/step - loss: 0.0023 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0022 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0019 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 6ms/step - loss: 0.0014 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 4ms/step - loss: 8.9536e-04 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 4ms/step - loss: 4.7701e-04 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 5ms/step - loss: 3.6461e-04 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 4ms/step - loss: 5.7630e-04 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0011 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 3ms/step - loss: 0.0014 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0011 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 7ms/step - loss: 4.0726e-04 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 3ms/step - loss: 3.6542e-04 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 3ms/step - loss: 7.2810e-04 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 4ms/step - loss: 7.8679e-04 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 4ms/step - loss: 5.7591e-04 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0078 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 5ms/step - loss: 0.0064 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 7ms/step - loss: 0.0047 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 5ms/step - loss: 0.0031 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0018 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 3ms/step - loss: 9.3522e-04 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 7ms/step - loss: 4.6037e-04 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 6ms/step - loss: 3.2995e-04 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 4ms/step - loss: 4.1988e-04 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0015 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0029 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0033 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0018 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0013 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 4ms/step - loss: 8.7183e-04 - top_k_categorical_accuracy: 0.4062
# 1/1 [==============================] - 0s 4ms/step - loss: 5.0666e-04 - top_k_categorical_accuracy: 0.4375
# 1/1 [==============================] - 0s 4ms/step - loss: 4.6142e-04 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 9ms/step - loss: 9.9903e-04 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 3ms/step - loss: 0.0016 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0013 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 4ms/step - loss: 7.7847e-04 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 3ms/step - loss: 3.1929e-04 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 5ms/step - loss: 5.1639e-04 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 3ms/step - loss: 5.9405e-04 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 4ms/step - loss: 4.7381e-04 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 4ms/step - loss: 6.7653e-04 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0044 - top_k_categorical_accuracy: 0.5312
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0016 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0013 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 7ms/step - loss: 0.0028 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0022 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 4ms/step - loss: 9.1544e-04 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 5ms/step - loss: 0.0013 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0023 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 7ms/step - loss: 0.0019 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 4ms/step - loss: 6.4917e-04 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 3ms/step - loss: 4.2727e-04 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0012 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 5ms/step - loss: 0.0037 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 5ms/step - loss: 0.0027 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0018 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0016 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0013 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0036 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 3ms/step - loss: 0.0028 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0027 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0035 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 3ms/step - loss: 0.0033 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0024 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 3ms/step - loss: 0.0012 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 3ms/step - loss: 6.6825e-04 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 4ms/step - loss: 9.8550e-04 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0112 - top_k_categorical_accuracy: 0.3750
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0053 - top_k_categorical_accuracy: 0.4062
# 1/1 [==============================] - 0s 3ms/step - loss: 9.0299e-04 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 5ms/step - loss: 0.0027 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0068 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0064 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0023 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 4ms/step - loss: 5.5895e-04 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0023 - top_k_categorical_accuracy: 0.5625
# 1/1 [==============================] - 0s 7ms/step - loss: 0.0043 - top_k_categorical_accuracy: 0.5312
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0040 - top_k_categorical_accuracy: 0.5625
# 1/1 [==============================] - 0s 3ms/step - loss: 0.0022 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 4ms/step - loss: 6.1269e-04 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 4ms/step - loss: 9.8280e-04 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0018 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0018 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 5ms/step - loss: 0.0014 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 3ms/step - loss: 8.8736e-04 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 3ms/step - loss: 9.9028e-04 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0037 - top_k_categorical_accuracy: 0.2812
# 1/1 [==============================] - 0s 6ms/step - loss: 0.0029 - top_k_categorical_accuracy: 0.2812
# 1/1 [==============================] - 0s 4ms/step - loss: 9.1859e-04 - top_k_categorical_accuracy: 0.5000
# 1/1 [==============================] - 0s 4ms/step - loss: 8.1162e-04 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0023 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0035 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0011 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 4ms/step - loss: 3.0299e-04 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0014 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0025 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 3ms/step - loss: 0.0030 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0016 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 4ms/step - loss: 4.9265e-04 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 4ms/step - loss: 4.3972e-04 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 7ms/step - loss: 0.0012 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0014 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 7ms/step - loss: 9.1216e-04 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 4ms/step - loss: 4.1798e-04 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 4ms/step - loss: 5.4123e-04 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 4ms/step - loss: 8.2607e-04 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 4ms/step - loss: 8.1850e-04 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 3ms/step - loss: 6.0471e-04 - top_k_categorical_accuracy: 0.5000
# 1/1 [==============================] - 0s 4ms/step - loss: 3.6945e-04 - top_k_categorical_accuracy: 0.5938
# 1/1 [==============================] - 0s 4ms/step - loss: 2.2492e-04 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 4ms/step - loss: 3.3259e-04 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 4ms/step - loss: 3.9782e-04 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 6ms/step - loss: 3.3422e-04 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 10ms/step - loss: 1.9309e-04 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0140 - top_k_categorical_accuracy: 0.5312
# 1/1 [==============================] - 0s 3ms/step - loss: 2.0557e-04 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 4ms/step - loss: 8.6608e-04 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 5ms/step - loss: 0.0016 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0012 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 3ms/step - loss: 5.9468e-04 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 5ms/step - loss: 4.7724e-04 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 4ms/step - loss: 4.3542e-04 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 4ms/step - loss: 4.5743e-04 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 3ms/step - loss: 9.2770e-04 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 7ms/step - loss: 9.8348e-04 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 6ms/step - loss: 8.8621e-04 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 6ms/step - loss: 7.7080e-04 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 3ms/step - loss: 3.3890e-04 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 7ms/step - loss: 7.5414e-05 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0040 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0035 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 6ms/step - loss: 0.0027 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0018 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 3ms/step - loss: 0.0011 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 4ms/step - loss: 7.5362e-04 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 8ms/step - loss: 4.3777e-04 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 4ms/step - loss: 7.0982e-04 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 4ms/step - loss: 9.1449e-04 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0013 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0021 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0027 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0021 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 4ms/step - loss: 7.7116e-04 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 5ms/step - loss: 2.2636e-04 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 4ms/step - loss: 8.1031e-04 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0029 - top_k_categorical_accuracy: 0.6875
# 1/1 [==============================] - 0s 3ms/step - loss: 0.0028 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 3ms/step - loss: 0.0017 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 4ms/step - loss: 9.4682e-04 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 4ms/step - loss: 6.9036e-04 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 3ms/step - loss: 5.5870e-04 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 4ms/step - loss: 6.9176e-04 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 3ms/step - loss: 0.0010 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0012 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 5ms/step - loss: 0.0010 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 4ms/step - loss: 5.1271e-04 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 4ms/step - loss: 2.8958e-04 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 5ms/step - loss: 5.1088e-04 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 6ms/step - loss: 0.0012 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0012 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 4ms/step - loss: 8.6220e-04 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0064 - top_k_categorical_accuracy: 0.4375
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0033 - top_k_categorical_accuracy: 0.6562
# 1/1 [==============================] - 0s 4ms/step - loss: 9.3828e-04 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0029 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0038 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0015 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 4ms/step - loss: 2.5132e-04 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0015 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0024 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 7ms/step - loss: 0.0034 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 3ms/step - loss: 0.0019 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0058 - top_k_categorical_accuracy: 0.5000
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0024 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0035 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 6ms/step - loss: 0.0055 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 7ms/step - loss: 0.0033 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 4ms/step - loss: 5.1819e-04 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 5ms/step - loss: 0.0029 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0045 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0029 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 3ms/step - loss: 0.0010 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 3ms/step - loss: 0.0018 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 3ms/step - loss: 0.0034 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0026 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 4ms/step - loss: 7.9966e-04 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 4ms/step - loss: 7.1910e-04 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0024 - top_k_categorical_accuracy: 0.4062
# 1/1 [==============================] - 0s 3ms/step - loss: 0.0043 - top_k_categorical_accuracy: 0.4062
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0031 - top_k_categorical_accuracy: 0.4688
# 1/1 [==============================] - 0s 3ms/step - loss: 0.0015 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 3ms/step - loss: 0.0010 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 4ms/step - loss: 9.6042e-04 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0013 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 6ms/step - loss: 0.0012 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 4ms/step - loss: 5.0894e-04 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0011 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0015 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0017 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0016 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0014 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0010 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 4ms/step - loss: 7.2312e-04 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 3ms/step - loss: 3.1248e-04 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 4ms/step - loss: 5.6165e-04 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0010 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0014 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0010 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 6ms/step - loss: 5.5120e-04 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 3ms/step - loss: 1.5920e-04 - top_k_categorical_accuracy: 0.9688
# 1/1 [==============================] - 0s 4ms/step - loss: 1.6577e-04 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 4ms/step - loss: 5.1711e-04 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 4ms/step - loss: 8.3260e-04 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 6ms/step - loss: 0.0027 - top_k_categorical_accuracy: 0.5938
# 1/1 [==============================] - 0s 4ms/step - loss: 9.9741e-04 - top_k_categorical_accuracy: 0.7812
# 1/1 [==============================] - 0s 4ms/step - loss: 3.6249e-04 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 5ms/step - loss: 0.0015 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 3ms/step - loss: 0.0023 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0052 - top_k_categorical_accuracy: 0.6250
# 1/1 [==============================] - 0s 3ms/step - loss: 0.3813 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 4ms/step - loss: 52.4221 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 5ms/step - loss: 0.9124 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0094 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0324 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 4ms/step - loss: 0.1847 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 4ms/step - loss: 0.4445 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 3ms/step - loss: 0.6116 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 4ms/step - loss: 0.5518 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 4ms/step - loss: 0.3751 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 7ms/step - loss: 0.2546 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 4ms/step - loss: 0.1734 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 4ms/step - loss: 0.1475 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 5ms/step - loss: 0.1121 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0842 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 6ms/step - loss: 0.0729 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 7ms/step - loss: 0.0602 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0476 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0445 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 3ms/step - loss: 0.0628 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 4ms/step - loss: 0.8383 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 4ms/step - loss: 0.1066 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 4ms/step - loss: 1.2953 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 4ms/step - loss: 0.1339 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 4ms/step - loss: 0.1400 - top_k_categorical_accuracy: 0.3438
# 1/1 [==============================] - 0s 4ms/step - loss: 0.1413 - top_k_categorical_accuracy: 0.3125
# 1/1 [==============================] - 0s 4ms/step - loss: 0.1391 - top_k_categorical_accuracy: 0.3438
# 1/1 [==============================] - 0s 3ms/step - loss: 0.0260 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 4ms/step - loss: 0.1659 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 3ms/step - loss: 0.0193 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0265 - top_k_categorical_accuracy: 0.3125
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0659 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0860 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 3ms/step - loss: 0.0863 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0765 - top_k_categorical_accuracy: 0.3750
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0653 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 3ms/step - loss: 0.0576 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0334 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0262 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0212 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0167 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0240 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 7ms/step - loss: 0.0139 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0163 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0125 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 5ms/step - loss: 0.0110 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 5ms/step - loss: 0.0130 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0118 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 3ms/step - loss: 0.0102 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0108 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0081 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0132 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0078 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 3ms/step - loss: 0.0129 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0064 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0090 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0049 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 3ms/step - loss: 0.0065 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 3ms/step - loss: 0.0037 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0044 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 6ms/step - loss: 0.0036 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0024 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0040 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0192 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 3ms/step - loss: 0.0191 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 5ms/step - loss: 0.0139 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0125 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0093 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 3ms/step - loss: 0.0066 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0117 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0052 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 3ms/step - loss: 0.0028 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 5ms/step - loss: 0.0094 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0071 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0033 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0018 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0036 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0082 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0204 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0965 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 4ms/step - loss: 0.1247 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0107 - top_k_categorical_accuracy: 0.4375
# 1/1 [==============================] - 0s 5ms/step - loss: 0.0880 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0189 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 5ms/step - loss: 0.0492 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0440 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0391 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 7ms/step - loss: 0.0173 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0394 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0053 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0309 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 7ms/step - loss: 0.0180 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0178 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 3ms/step - loss: 0.0368 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0113 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 3ms/step - loss: 0.0244 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0163 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 5ms/step - loss: 0.0021 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0140 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0101 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0047 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0134 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0115 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0048 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 6ms/step - loss: 0.0068 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 5ms/step - loss: 0.0075 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 5ms/step - loss: 0.0020 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 5ms/step - loss: 0.0026 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 6ms/step - loss: 0.0062 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0043 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0027 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0044 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0033 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 11ms/step - loss: 0.0010 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 5ms/step - loss: 0.0013 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0021 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0019 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0012 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0016 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0016 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0012 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0012 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 4ms/step - loss: 6.7378e-04 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 4ms/step - loss: 5.1873e-04 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0012 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0015 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0014 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 4ms/step - loss: 8.9363e-04 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 4ms/step - loss: 8.1112e-04 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 3ms/step - loss: 9.1082e-04 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0011 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0031 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0020 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0011 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 4ms/step - loss: 9.0367e-04 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 4ms/step - loss: 9.8505e-04 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 4ms/step - loss: 9.1389e-04 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0012 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 6ms/step - loss: 0.0012 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 5ms/step - loss: 7.5077e-04 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 4ms/step - loss: 6.9840e-04 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0010 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0010 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 4ms/step - loss: 9.0386e-04 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0014 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 3ms/step - loss: 0.0011 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 4ms/step - loss: 6.9341e-04 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 6ms/step - loss: 2.5979e-04 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 4ms/step - loss: 4.9023e-04 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 4ms/step - loss: 7.7814e-04 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 4ms/step - loss: 8.5855e-04 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 4ms/step - loss: 7.1477e-04 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 4ms/step - loss: 4.6872e-04 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 4ms/step - loss: 2.8749e-04 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 4ms/step - loss: 3.6144e-04 - top_k_categorical_accuracy: 1.0000
# ...
# 1/1 [==============================] - 0s 8ms/step - loss: 1.7877e-04 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 4ms/step - loss: 2.9061e-04 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 4ms/step - loss: 1.6458e-04 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 4ms/step - loss: 1.3279e-04 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0033 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 3ms/step - loss: 0.0025 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 3ms/step - loss: 0.0016 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0011 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 4ms/step - loss: 7.7804e-04 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 4ms/step - loss: 3.9429e-04 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 4ms/step - loss: 3.2021e-04 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 4ms/step - loss: 6.0650e-04 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 5ms/step - loss: 8.7503e-04 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 13ms/step - loss: 8.9929e-04 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 5ms/step - loss: 9.9947e-04 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 4ms/step - loss: 8.6134e-04 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 4ms/step - loss: 5.6630e-04 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 4ms/step - loss: 2.8149e-04 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 4ms/step - loss: 2.2221e-04 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 4ms/step - loss: 2.1160e-04 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 4ms/step - loss: 2.3726e-04 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 6ms/step - loss: 2.5550e-04 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 4ms/step - loss: 4.9457e-04 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 4ms/step - loss: 4.6967e-04 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 4ms/step - loss: 4.1682e-04 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 5ms/step - loss: 4.7670e-04 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 4ms/step - loss: 4.2556e-04 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 4ms/step - loss: 1.4922e-04 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 4ms/step - loss: 8.8982e-05 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 5ms/step - loss: 2.1655e-04 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 7ms/step - loss: 3.7362e-04 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 4ms/step - loss: 4.1243e-04 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 4ms/step - loss: 5.5033e-04 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 4ms/step - loss: 2.0723e-04 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 4ms/step - loss: 7.2372e-05 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 4ms/step - loss: 9.5652e-05 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 4ms/step - loss: 1.4202e-04 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 4ms/step - loss: 1.3743e-04 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 4ms/step - loss: 1.2275e-04 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 4ms/step - loss: 1.1619e-04 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 4ms/step - loss: 1.4137e-04 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 3ms/step - loss: 1.3741e-04 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 4ms/step - loss: 8.0165e-05 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 6ms/step - loss: 3.0588e-05 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 4ms/step - loss: 1.1908e-04 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0014 - top_k_categorical_accuracy: 0.4062
# 1/1 [==============================] - 0s 3ms/step - loss: 7.0306e-04 - top_k_categorical_accuracy: 0.4688
# 1/1 [==============================] - 0s 4ms/step - loss: 4.2734e-04 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 4ms/step - loss: 6.8435e-04 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 4ms/step - loss: 2.8374e-04 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 4ms/step - loss: 2.3765e-04 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 4ms/step - loss: 5.9120e-04 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 4ms/step - loss: 3.0068e-04 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 5ms/step - loss: 2.5085e-04 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 6ms/step - loss: 5.0269e-04 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 7ms/step - loss: 3.5816e-04 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 4ms/step - loss: 2.3080e-04 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 4ms/step - loss: 4.6625e-04 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 4ms/step - loss: 3.0311e-04 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 4ms/step - loss: 1.5562e-04 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 4ms/step - loss: 3.5021e-04 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 3ms/step - loss: 3.1593e-04 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 6ms/step - loss: 1.0626e-04 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 13ms/step - loss: 3.4146e-04 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 4ms/step - loss: 2.7672e-04 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 4ms/step - loss: 9.8053e-05 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 5ms/step - loss: 5.0779e-04 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 4ms/step - loss: 5.4847e-04 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 8ms/step - loss: 3.2036e-04 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 4ms/step - loss: 3.0206e-04 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 4ms/step - loss: 2.7645e-04 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 4ms/step - loss: 1.2749e-04 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 4ms/step - loss: 6.0165e-05 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 4ms/step - loss: 1.0693e-04 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 3ms/step - loss: 8.4445e-05 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 4ms/step - loss: 6.7007e-05 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 5ms/step - loss: 1.3677e-04 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 3ms/step - loss: 1.8771e-04 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 4ms/step - loss: 1.7149e-04 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 4ms/step - loss: 1.5647e-04 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 3ms/step - loss: 3.9717e-04 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 5ms/step - loss: 1.7690e-04 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 4ms/step - loss: 1.6815e-04 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 5ms/step - loss: 2.2717e-04 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 6ms/step - loss: 2.1561e-04 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 4ms/step - loss: 2.2659e-04 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 4ms/step - loss: 2.4095e-04 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 4ms/step - loss: 2.3820e-04 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 4ms/step - loss: 2.2245e-04 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 8ms/step - loss: 1.9279e-04 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 4ms/step - loss: 1.4631e-04 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 4ms/step - loss: 3.5975e-04 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 4ms/step - loss: 2.8285e-04 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 4ms/step - loss: 1.7791e-04 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 4ms/step - loss: 2.1403e-04 - top_k_categorical_accuracy: 0.5625
# 1/1 [==============================] - 0s 7ms/step - loss: 1.8011e-04 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 4ms/step - loss: 9.5611e-05 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 4ms/step - loss: 8.1451e-05 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 5ms/step - loss: 1.7828e-04 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 7ms/step - loss: 1.5463e-04 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 4ms/step - loss: 1.4556e-04 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 3ms/step - loss: 7.0259e-05 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 6ms/step - loss: 2.3522e-04 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 4ms/step - loss: 1.2564e-04 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 6ms/step - loss: 5.1220e-05 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 4ms/step - loss: 1.0456e-04 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 5ms/step - loss: 7.7687e-05 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 4ms/step - loss: 7.3798e-05 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 4ms/step - loss: 1.0774e-04 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 3ms/step - loss: 1.2025e-04 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 4ms/step - loss: 4.0026e-05 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 6ms/step - loss: 9.8337e-05 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 4ms/step - loss: 1.2714e-04 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 4ms/step - loss: 9.9645e-05 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 3ms/step - loss: 2.6648e-05 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 4ms/step - loss: 1.4703e-04 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 4ms/step - loss: 1.4131e-04 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 4ms/step - loss: 4.3107e-05 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 4ms/step - loss: 6.4258e-05 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 4ms/step - loss: 3.8491e-04 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 4ms/step - loss: 1.5211e-04 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 6ms/step - loss: 1.8516e-04 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0014 - top_k_categorical_accuracy: 0.2812
# 1/1 [==============================] - 0s 4ms/step - loss: 3.1790e-04 - top_k_categorical_accuracy: 0.6562
# 1/1 [==============================] - 0s 4ms/step - loss: 5.7073e-04 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 4ms/step - loss: 9.1326e-04 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 4ms/step - loss: 9.4811e-05 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 4ms/step - loss: 3.2623e-04 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 19ms/step - loss: 5.3093e-04 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 5ms/step - loss: 2.0993e-04 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 3ms/step - loss: 1.6480e-04 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 6ms/step - loss: 3.4994e-04 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 5ms/step - loss: 1.4305e-04 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 4ms/step - loss: 9.2833e-04 - top_k_categorical_accuracy: 0.5938
# 1/1 [==============================] - 0s 6ms/step - loss: 6.3059e-04 - top_k_categorical_accuracy: 0.6250
# 1/1 [==============================] - 0s 3ms/step - loss: 3.1173e-04 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 3ms/step - loss: 2.6236e-04 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 5ms/step - loss: 1.8251e-04 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 4ms/step - loss: 3.6417e-04 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 4ms/step - loss: 3.8607e-04 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 4ms/step - loss: 1.7700e-04 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 3ms/step - loss: 2.5868e-04 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 4ms/step - loss: 4.8734e-04 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 4ms/step - loss: 3.1839e-04 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 4ms/step - loss: 9.5225e-04 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 4ms/step - loss: 5.7608e-04 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 4ms/step - loss: 9.2687e-05 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 5ms/step - loss: 4.2976e-04 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 4ms/step - loss: 7.2629e-04 - top_k_categorical_accuracy: 1.0000

# %% [markdown]
# # 4. Visualize Results

# %% [markdown]
# #### 4.1 Comparison of actual vs maximum rewards.

# %%
def sortGenresByMean(meanValues):
  return np.array(meanValues).argsort()[-len(meanValues):][::-1]

# %%
snapshots = 9
dataStep = math.floor(len(userSequencePool[user_index]) / snapshots)
maximumCorrelationValues = []
actualCorrelationValues = []

# Maximum rewards per genre
maximumRewardsSum = np.zeros(18)
for ratingIndex, rating in enumerate(userSequencePool[user_index]):
  if ratingIndex % dataStep == 0:
    maximumCorrelationValues.append(np.array(maximumRewardsSum))
  for i, genre in enumerate(allGenres):
    if genre in rating[0]:
      if rating[1] == 2:
        maximumRewardsSum[i] += 0.3

      if rating[1] == 1:
        maximumRewardsSum[i] -= 0
      
      if rating[1] == 0:
        maximumRewardsSum[i] += 0.1

# Actual rewards per genre
actualRewardsSum = np.zeros(18)
rewardsOverTime = []
for ratingIndex, pair in enumerate(genreRewards):
  if ratingIndex % dataStep == 0:
    actualCorrelationValues.append(np.array(actualRewardsSum))
  rewardsOverTime.append(pair[1])
  actualRewardsSum[pair[0]] += pair[1]

# Correlation analysis
correlationValues = []
significanceValues = []
for corrValueIndex, corrValue in enumerate(maximumCorrelationValues):
  correlationValues.append(np.corrcoef(maximumCorrelationValues[corrValueIndex], actualCorrelationValues[corrValueIndex])[0][1])
  significanceValues.append(pearsonr(maximumCorrelationValues[corrValueIndex], actualCorrelationValues[corrValueIndex]))

correlationValues = np.where(np.isnan(correlationValues), 0, correlationValues)
labels = [i * dataStep for i in range(0, snapshots+1)]

plt.figure(figsize=(10,7))
plt.xlabel("Snapshot (Episode)")
plt.ylabel("Correlation")
plt.xticks(np.arange(0, snapshots+1), labels)
plt.yticks(np.arange(0, 1, step=0.1))
plt.plot(correlationValues, marker='o', color="lightslategrey")
plt.plot(significanceValues, marker='o', color="lightslategrey")
plt.title("Change of reward correlation between predicted and optimal values")

# Plot
groupedData = pd.DataFrame(np.c_[maximumRewardsSum, actualRewardsSum], index=allGenres)
ax = groupedData.plot.bar(
    figsize=(10,7), 
    xlabel="Genres",
    ylabel="Reward",
    title="Distribution of rewards for predicted and optimal values per gerne (last episode)",
    color=["lightslategrey", "lightsteelblue"]
)
ax.legend(["Maximum rewards", "Actual rewards"]);
# Out:
# /usr/local/lib/python3.6/dist-packages/numpy/lib/function_base.py:2559: RuntimeWarning: invalid value encountered in true_divide
#   c /= stddev[:, None]
# /usr/local/lib/python3.6/dist-packages/scipy/stats/stats.py:3508: PearsonRConstantInputWarning: An input array is constant; the correlation coefficent is not defined.
#   warnings.warn(PearsonRConstantInputWarning())
# (0.921106662928759, 5.879002793442869e-08)

# %%
print('\n\nMaximum Ranking:\n')
sortedGenreByMaximumReward = sortGenresByMean(maximumRewardsSum)
for i, genreIndex in enumerate(sortedGenreByMaximumReward):
  print('%s: %s' % (i +1, allGenres[genreIndex]))
# Out:
# Maximum Ranking:
#
# 1: Action
# 2: Drama
# 3: Thriller
# 4: Sci-Fi
# 5: Adventure
# 6: Crime
# 7: Comedy
# 8: Fantasy
# 9: Mystery
# 10: Animation
# 11: Romance
# 12: Children
# 13: Horror
# 14: War
# 15: Western
# 16: Film-Noir
# 17: Musical
# 18: Documentary

# %%
print('\n\nActual Ranking:\n')
sortedGenreByActualReward = sortGenresByMean(actualRewardsSum)
for i, genreIndex in enumerate(sortedGenreByActualReward):
  print('%s: %s' % (i +1, allGenres[genreIndex]))
# Out:
# Actual Ranking:
#
# 1: Drama
# 2: Sci-Fi
# 3: Adventure
# 4: Thriller
# 5: Action
# 6: Crime
# 7: Comedy
# 8: Fantasy
# 9: Mystery
# 10: Romance
# 11: Horror
# 12: Animation
# 13: Film-Noir
# 14: Children
# 15: War
# 16: Western
# 17: Documentary
# 18: Musical

# %%
def mapRatingsToEpisodes(ratings):
  for genreIndex, array in enumerate(ratings):
    arraySteps = list(range(0, len(genreRewards)))
    currentGenreDevelopment = np.zeros(len(genreRewards))
    increment = 0
    for j, value in enumerate(currentGenreDevelopment):
      for val in array:
        if val[0] == j:
          increment = val[1]
      currentGenreDevelopment[j] = increment
    ratings[genreIndex] = currentGenreDevelopment
  return ratings  

def createGenreMeanValues(ratingsPerGenre, step):
  allGenreMeanValues = [[] for i in allGenres]
  for genreIndex, genre in enumerate(ratingsPerGenre):
    genreMeanValues = []
    for episodeIndex, episode in enumerate(genre):
      snapshot = episodeIndex + 1
      if snapshot % step == 0:
        genreMeanValues.append(np.mean(genre[:episodeIndex]))
    allGenreMeanValues[genreIndex].append(genreMeanValues) 
  return allGenreMeanValues


def sumMeanValuesPerStep(rewards):
  sumMeanValuesPerSnapshot = [[] for snapshot in range(0, snapshots)]
  for snapshotIndex, snapshot in enumerate(range(0, snapshots)):
    for genreIndex, genre in enumerate(allGenres):
      sumMeanValuesPerSnapshot[snapshotIndex].append(rewards[genreIndex][0][snapshotIndex])
  return [np.mean(item) for item in sumMeanValuesPerSnapshot]


actualRewards = [[] for i in allGenres]
maximumRewards = [[] for i in allGenres]
snapshots = 9
dataStep = math.floor(len(userSequencePool[user_index]) / snapshots)

# Maximum rewards per genre
for ratingIndex, rating in enumerate(userSequencePool[user_index]):
  for genreIndex, genre in enumerate(allGenres):
      if genre in rating[0]:
        if rating[1] == 2:
          maximumRewards[genreIndex].append([ratingIndex, 0.3])

        if rating[1] == 1:
          maximumRewards[genreIndex].append([ratingIndex, 0])
        
        if rating[1] == 0:
          maximumRewards[genreIndex].append([ratingIndex, 0.1])

# Actual rewards per genre
for i, pair in enumerate(genreRewards):
  actualRewards[pair[0]].append([i, pair[1]])

maximumRewards = mapRatingsToEpisodes(maximumRewards)
actualRewards = mapRatingsToEpisodes(actualRewards)

maximumRewards = createGenreMeanValues(maximumRewards, dataStep)
actualRewards = createGenreMeanValues(actualRewards, dataStep)

maximumRewards = sumMeanValuesPerStep(maximumRewards)
actualRewards = sumMeanValuesPerStep(actualRewards)

x = np.arange(np.array(snapshots))
width = 0.3
plt.figure(figsize=(20,10))
plt.xlabel("Snapshots")
plt.ylabel("Reward")
plt.title("Maximum vs. Actual Mean")

plt.bar(x - width/2 + 1, np.array(maximumRewards), width=width, label="Maximum")
plt.bar(x + width/2 + 1, np.array(actualRewards), width=width, label="Actual")

plt.legend()
plt.show()

# %% [markdown]
# #### 4.2 Genre reward sum per episode

# %%
numColors = len(allGenres)
cm = plt.get_cmap('tab20c')
genreChange = [[] for i in allGenres]
for ratingIndex, genreRewardPair in enumerate(genreRewards):
  genreChange[genreRewardPair[0]].append([ratingIndex, genreRewardPair[1]])

fig = plt.figure(figsize=(12,7))
ax = fig.add_subplot(111)
plt.xlabel("User Rating (Episode)")
plt.ylabel("Reward")
plt.title("Change of the total reward amount for each genre by predicted values")
ax.set_prop_cycle('color', [cm(1.*i/numColors) for i in range(numColors)])

for genre, array in enumerate(genreChange):
  arraySteps = list(range(0, len(genreRewards)))
  currentGenreChange = np.zeros(len(genreRewards))
  increment = 0
  for j, value in enumerate(currentGenreChange):
    for val in array:
      if val[0] == j:
        increment += val[1]
    currentGenreChange[j] = increment
  ax.plot(arraySteps, currentGenreChange, label=allGenres[genre])
ax.legend(bbox_to_anchor=(1, 1.015), loc='upper left')

# %% [markdown]
# #### 4.3 Genre reward sum distribution per episode

# %%
def getPositiveValues(val):
  return (-1) * val

numColors = len(allGenres)
cm = plt.get_cmap('tab20c')
genresStacked = []
genreDevelopment = [[] for i in allGenres]
genresStackedNormalized = [[] for i in allGenres]
episodeMins = list(np.zeros(len(genreRewards)))

for i, pair in enumerate(genreRewards):
  genreDevelopment[pair[0]].append([i, pair[1]])

for genre, array in enumerate(genreDevelopment):
  increment = 0
  currentGenreDevelopment = np.zeros(len(genreRewards))
  for j, value in enumerate(currentGenreDevelopment):
    for val in array:
      if val[0] == j:
        increment += val[1]
    currentGenreDevelopment[j] = increment
  genresStacked.append(currentGenreDevelopment)

  for e, episodeValue in enumerate(genresStacked[genre]):
    if episodeValue < episodeMins[e]:
      episodeMins[e] = episodeValue

for episodeMinInd, episodeMin in enumerate(episodeMins):
  episodeMins[episodeMinInd] = getPositiveValues(episodeMin)


for genreInd, genreArray in enumerate(genresStacked):
  for episodeInd, episodeValue in enumerate(genreArray):
    genresStackedNormalized[genreInd].append(episodeValue + episodeMins[episodeInd])
genresStacked = genresStackedNormalized

width = 1
fig = plt.figure(figsize=(12,7))
ax = fig.add_subplot(111)
ax.set_prop_cycle('color', [cm(1.*i/numColors) for i in range(numColors)])

p1 = plt.bar(list(range(0, len(genreRewards))), np.array(genresStacked[0]), width)
p2 = plt.bar(list(range(0, len(genreRewards))), np.array(genresStacked[1]), width, bottom=np.array(genresStacked[0]))
p3 = plt.bar(list(range(0, len(genreRewards))), np.array(genresStacked[2]), width, bottom=np.array(genresStacked[0]) + np.array(genresStacked[1]))
p4 = plt.bar(list(range(0, len(genreRewards))), np.array(genresStacked[3]), width, bottom=np.array(genresStacked[0]) + np.array(genresStacked[1]) + np.array(genresStacked[2]))
p5 = plt.bar(list(range(0, len(genreRewards))), np.array(genresStacked[4]), width, bottom=np.array(genresStacked[0]) + np.array(genresStacked[1]) + np.array(genresStacked[2]) + np.array(genresStacked[3]))
p6 = plt.bar(list(range(0, len(genreRewards))), np.array(genresStacked[5]), width, bottom=np.array(genresStacked[0]) + np.array(genresStacked[1]) + np.array(genresStacked[2]) + np.array(genresStacked[3]) + np.array(genresStacked[4]))
p7 = plt.bar(list(range(0, len(genreRewards))), np.array(genresStacked[6]), width, bottom=np.array(genresStacked[0]) + np.array(genresStacked[1]) + np.array(genresStacked[2]) + np.array(genresStacked[3]) + np.array(genresStacked[4]) + np.array(genresStacked[5]))
p8 = plt.bar(list(range(0, len(genreRewards))), np.array(genresStacked[7]), width, bottom=np.array(genresStacked[0]) + np.array(genresStacked[1]) + np.array(genresStacked[2]) + np.array(genresStacked[3]) + np.array(genresStacked[4]) + np.array(genresStacked[5]) + np.array(genresStacked[6]))
p9 = plt.bar(list(range(0, len(genreRewards))), np.array(genresStacked[8]), width, bottom=np.array(genresStacked[0]) + np.array(genresStacked[1]) + np.array(genresStacked[2]) + np.array(genresStacked[3]) + np.array(genresStacked[4]) + np.array(genresStacked[5]) + np.array(genresStacked[6]) + np.array(genresStacked[7]))
p10 = plt.bar(list(range(0, len(genreRewards))), np.array(genresStacked[9]), width, bottom=np.array(genresStacked[0]) + np.array(genresStacked[1]) + np.array(genresStacked[2]) + np.array(genresStacked[3]) + np.array(genresStacked[4]) + np.array(genresStacked[5]) + np.array(genresStacked[6]) + np.array(genresStacked[7]) + np.array(genresStacked[8]))
p11 = plt.bar(list(range(0, len(genreRewards))), np.array(genresStacked[10]), width, bottom=np.array(genresStacked[0]) + np.array(genresStacked[1]) + np.array(genresStacked[2]) + np.array(genresStacked[3]) + np.array(genresStacked[4]) + np.array(genresStacked[5]) + np.array(genresStacked[6]) + np.array(genresStacked[7]) + np.array(genresStacked[8]) + np.array(genresStacked[9]))
p12 = plt.bar(list(range(0, len(genreRewards))), np.array(genresStacked[11]), width, bottom=np.array(genresStacked[0]) + np.array(genresStacked[1]) + np.array(genresStacked[2]) + np.array(genresStacked[3]) + np.array(genresStacked[4]) + np.array(genresStacked[5]) + np.array(genresStacked[6]) + np.array(genresStacked[7]) + np.array(genresStacked[8]) + np.array(genresStacked[9]) + np.array(genresStacked[10]))
p13 = plt.bar(list(range(0, len(genreRewards))), np.array(genresStacked[12]), width, bottom=np.array(genresStacked[0]) + np.array(genresStacked[1]) + np.array(genresStacked[2]) + np.array(genresStacked[3]) + np.array(genresStacked[4]) + np.array(genresStacked[5]) + np.array(genresStacked[6]) + np.array(genresStacked[7]) + np.array(genresStacked[8]) + np.array(genresStacked[9]) + np.array(genresStacked[10]) + np.array(genresStacked[11]))
p14 = plt.bar(list(range(0, len(genreRewards))), np.array(genresStacked[13]), width, bottom=np.array(genresStacked[0]) + np.array(genresStacked[1]) + np.array(genresStacked[2]) + np.array(genresStacked[3]) + np.array(genresStacked[4]) + np.array(genresStacked[5]) + np.array(genresStacked[6]) + np.array(genresStacked[7]) + np.array(genresStacked[8]) + np.array(genresStacked[9]) + np.array(genresStacked[10]) + np.array(genresStacked[11]) + np.array(genresStacked[12]))
p15 = plt.bar(list(range(0, len(genreRewards))), np.array(genresStacked[14]), width, bottom=np.array(genresStacked[0]) + np.array(genresStacked[1]) + np.array(genresStacked[2]) + np.array(genresStacked[3]) + np.array(genresStacked[4]) + np.array(genresStacked[5]) + np.array(genresStacked[6]) + np.array(genresStacked[7]) + np.array(genresStacked[8]) + np.array(genresStacked[9]) + np.array(genresStacked[10]) + np.array(genresStacked[11]) + np.array(genresStacked[12]) + np.array(genresStacked[13]))
p16 = plt.bar(list(range(0, len(genreRewards))), np.array(genresStacked[15]), width, bottom=np.array(genresStacked[0]) + np.array(genresStacked[1]) + np.array(genresStacked[2]) + np.array(genresStacked[3]) + np.array(genresStacked[4]) + np.array(genresStacked[5]) + np.array(genresStacked[6]) + np.array(genresStacked[7]) + np.array(genresStacked[8]) + np.array(genresStacked[9]) + np.array(genresStacked[10]) + np.array(genresStacked[11]) + np.array(genresStacked[12]) + np.array(genresStacked[13]) + np.array(genresStacked[14]))
p17 = plt.bar(list(range(0, len(genreRewards))), np.array(genresStacked[16]), width, bottom=np.array(genresStacked[0]) + np.array(genresStacked[1]) + np.array(genresStacked[2]) + np.array(genresStacked[3]) + np.array(genresStacked[4]) + np.array(genresStacked[5]) + np.array(genresStacked[6]) + np.array(genresStacked[7]) + np.array(genresStacked[8]) + np.array(genresStacked[9]) + np.array(genresStacked[10]) + np.array(genresStacked[11]) + np.array(genresStacked[12]) + np.array(genresStacked[13]) + np.array(genresStacked[14]) + np.array(genresStacked[15]))
p18 = plt.bar(list(range(0, len(genreRewards))), np.array(genresStacked[17]), width, bottom=np.array(genresStacked[0]) + np.array(genresStacked[1]) + np.array(genresStacked[2]) + np.array(genresStacked[3]) + np.array(genresStacked[4]) + np.array(genresStacked[5]) + np.array(genresStacked[6]) + np.array(genresStacked[7]) + np.array(genresStacked[8]) + np.array(genresStacked[9]) + np.array(genresStacked[10]) + np.array(genresStacked[11]) + np.array(genresStacked[12]) + np.array(genresStacked[13]) + np.array(genresStacked[14]) + np.array(genresStacked[15]) + np.array(genresStacked[16]))


plt.xlabel("User Rating")
plt.ylabel("Reward")
plt.title("Change of total reward distribution for each genre by predicted values")
plt.legend((p1[0], p2[0], p3[0], p4[0], p5[0], p6[0], p7[0], p8[0], p9[0], p10[0], p11[0], p12[0], p13[0], p14[0], p15[0], p16[0], p17[0], p18[0])[::-1], (allGenres)[::-1], bbox_to_anchor=(1, 1.015), loc='upper left')
plt.show()

# %% [markdown]
# #### 4.3 Means and ranking of all data

# %%
# Recommend five random movies from recommended genre

def handleUserEpisode(numberOfRecommendations, prediction):
  recommendedGenre = allGenres[np.argmax(prediction)]
  moviesOfRecommendedGenre = movies[movies[recommendedGenre] == True]

  randomMoviesOfRecommendedGenre = random.sample(list(np.array(moviesOfRecommendedGenre['movieId'])), numberOfRecommendations)

  print('%s %s Movie Recommendations: \n' % (numberOfRecommendations, recommendedGenre))
  for id in randomMoviesOfRecommendedGenre:
    print(movies[movies['movieId'] == id]['title']) # TODO: Add genres

handleUserEpisode(5, actualRewardsSum)

# TODO:
# Connect the UI
# Out:
# 5 Drama Movie Recommendations:
#
# 62416    Happy Flight (2008)
# Name: title, dtype: object
# 18818    Joe + Belle (2011)
# Name: title, dtype: object
# 2376    Name of the Rose, The (Name der Rose, Der) (1986)
# Name: title, dtype: object
# 9845    Ascent, The (Voskhozhdeniye) (1977)
# Name: title, dtype: object
# 7699    Crazy Stranger, The (Gadjo Dilo) (1997)
# Name: title, dtype: object

# %%
print("Mean of the global genre rating:\n")

genreMeanValues = []

for genre in allGenres:
  currentMean = getGenreMean(genre)
  genreMeanValues.append(currentMean)
  print('%s: %s' % (genre, round(currentMean, 3)))

print('\n\nGlobal Ranking:\n')
sortedGenreMeanValues = sortGenresByMean(genreMeanValues)
for i, genreIndex in enumerate(sortedGenreMeanValues):
  print('%s: %s' % (i +1, allGenres[genreIndex]))
# Out:
# Mean of the individual genre rating:
#
# Adventure: 3.511
# Action: 3.463
# Animation: 3.616
# Children: 3.432
# Comedy: 3.425
# Crime: 3.691
# Documentary: 3.705
# Drama: 3.688
# Fantasy: 3.505
# Film-Noir: 3.914
# Horror: 3.284
# Musical: 3.559
# Mystery: 3.672
# Romance: 3.55
# Sci-Fi: 3.477
# Thriller: 3.525
# War: 3.799
# Western: 3.589
#
#
# Global Ranking:
#
# 1: Film-Noir
# 2: War
# 3: Documentary
# 4: Crime
# 5: Drama
# 6: Mystery
# 7: Animation
# 8: Western
# 9: Musical
# 10: Romance
# 11: Thriller
# 12: Adventure
# 13: Fantasy
# 14: Sci-Fi
# 15: Action
# 16: Children
# 17: Comedy
# 18: Horror
