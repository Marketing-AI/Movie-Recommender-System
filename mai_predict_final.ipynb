# %% [markdown]
# <a href="https://colab.research.google.com/github/Marketing-AI/Recommendation-Application/blob/main/mai_predict_final.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Import libraries

import random
import math
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from collections import deque

import keras

# %% [markdown]
# # 1. Load Data

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# Load Movies
movies = pd.read_excel('/content/drive/MyDrive/Studium/MAI/Data/movies.xlsx')
movies.head()
# Out:
#    movieId  ...                                       genres
# 0        1  ...  Adventure,Animation,Children,Comedy,Fantasy
# 1        2  ...                   Adventure,Children,Fantasy
# 2        3  ...                               Comedy,Romance
# 3        4  ...                         Comedy,Drama,Romance
# 4        5  ...                                       Comedy
#
# [5 rows x 3 columns]

# %%
# Load Ratings
ratings = pd.read_excel('/content/drive/MyDrive/Studium/MAI/Data/ratings_genres.xlsx')
ratings.head()
# Out:
#    userId  movieId  rating   timestamp                       genres
# 0       1      296     5.0  1147880044  Comedy,Crime,Drama,Thriller
# 1       1      306     3.5  1147868817                        Drama
# 2       1      307     5.0  1147868828                        Drama
# 3       1      665     5.0  1147878820             Comedy,Drama,War
# 4       1      899     3.5  1147868510       Comedy,Musical,Romance

# %%
# Find user with the highest amount of ratings
ratings.userId.mode()
# Out:
# 0    2177
# dtype: int64

# %%
# Provide all possible genres
allGenres = [
               "Adventure",
               "Action",
               "Animation",
               "Children",
               "Comedy",
               "Crime",
               "Documentary",
               "Drama",
               "Fantasy",
               "Film-Noir",
               "Horror",
               "Musical",
               "Mystery",
               "Romance",
               "Sci-Fi",
               "Thriller",
               "War",
               "Western"
]

# %% [markdown]
# # 2. Process Data

# %%
# Initialize data processing methods

def getMoviesByGenre(handle):
  movies[handle] = movies['genres'].str.contains(handle)
  moviesByGenre = movies[movies[handle] == True]
  return moviesByGenre

def getRatingsByGenre(handle):
  ratings[handle] = ratings['genres'].str.contains(handle)
  ratingsByGenre = ratings[ratings[handle] == True]
  return ratingsByGenre

def getGenreMean(handle):
  return ratings.loc[ratings[handle] == True, 'rating'].mean()

def getMaxInList(maxMeans):
  return np.where(maxMeans == np.nanmax(maxMeans))

def identifyMaxGenres(maxMeans, userId):
  result = []
  for index in maxMeans:
    userMax = np.array(np.array(allGenres)[index])
    userMax = np.insert(userMax, 0, userId, axis=0)
    result.append(userMax)
  return result

# %%
# Add genre boolean for each movie

for genre in allGenres:
  getMoviesByGenre(genre)

print("Updated movie columns!")
movies.head()
# Out:
# Updated movie columns!
#    movieId                               title  ...    War Western
# 0        1                    Toy Story (1995)  ...  False   False
# 1        2                      Jumanji (1995)  ...  False   False
# 2        3             Grumpier Old Men (1995)  ...  False   False
# 3        4            Waiting to Exhale (1995)  ...  False   False
# 4        5  Father of the Bride Part II (1995)  ...  False   False
#
# [5 rows x 21 columns]

# %%
# Add genre boolean for each rating

for genre in allGenres:
  getRatingsByGenre(genre)

print("Updated genre columns!")
ratings.head()
# Out:
# Updated genre columns!
#    userId  movieId  rating   timestamp  ... Sci-Fi Thriller    War Western
# 0       1      296     5.0  1147880044  ...  False     True  False   False
# 1       1      306     3.5  1147868817  ...  False    False  False   False
# 2       1      307     5.0  1147868828  ...  False    False  False   False
# 3       1      665     5.0  1147878820  ...  False    False   True   False
# 4       1      899     3.5  1147868510  ...  False    False  False   False
#
# [5 rows x 23 columns]

# %%
# Create [genre, action] sequence (each pair will be one episode)

## Choose user from dataset
startAt = 3 # 2177
userAmount = 1

userSequencePool = []

for user in range(startAt, startAt + userAmount):
  userRatingSequence = []
  unsortedUserRatings = ratings[ratings['userId'] == user]
  userRatings = unsortedUserRatings.sort_values(by=['timestamp'])

  # Create actions from ratings
  for i, rating in userRatings.iterrows():    
    # Neutral
    observation = [rating['genres'], 0]

    # Positive
    if int(rating['rating']) >= 4.0:
      observation = [rating['genres'], 2]
    
    # Negative
    if int(rating['rating']) <= 2.0:
      observation = [rating['genres'], 1]
    
    userRatingSequence.append(observation)

  userSequencePool.append(userRatingSequence)

print('Number of ratings: %s' % (len(userSequencePool[0])))
print('Example of the appearance of one rating: %s' % userSequencePool[0][0])
# Out:
# Number of ratings: 656
# Example of the appearance of one rating: ['Comedy,Drama,Romance,War', 2]

# %% [markdown]
# # 3. Analyse Data

# %% [markdown]
# ### 3.1 Create Environment

# %%
# Create atrificial environment

class Environment:
  def __init__(self, user, action_space): 

    self.state = np.zeros(action_space)
    self.user = user
  
  # Calculate reward for the given action of an episode
  def episode(self, step, action):  
    correctlyPredicted = False
    currentUser = np.array(userSequencePool)[self.user]

    reward = -0.025
    
    for i, genre in enumerate(allGenres):
      if genre in currentUser[step][0] and i == action:
        correctlyPredicted = True

    if correctlyPredicted:
      # Neutral
      reward = 0.1

      # Positive
      if int(currentUser[step][1]) == 2:
        reward = 0.3

      # Negative
      if int(currentUser[step][1]) == 1:
        reward = -0.2

    return reward, currentUser[step]

  # Simulate the change of the environment
  def update_state(self, currentRating, reward):
    for i, genre in enumerate(allGenres):
      if genre in currentRating:
        self.state[i] += reward

# %% [markdown]
# ### 3.2 Create Agent

# %%
# Create agent

class Agent:
    def __init__(self, action_space, data):
        self.data = data
        self.data_length = len(self.data)
        self.action_space = action_space
        self.action_count = np.zeros(action_space)

        self.epsilon = 0.3
        self.learning_rate = 0.1
        self.discount_factor = 0.01
        self.batch_size = 32

        self.model = self.build_model()
        self.memory = deque(maxlen=100000)
        self.acc = []
        self.loss = []

    # Memorize current episode 
    def remember(self, reward, action, state, next_state, done):
        self.memory.append((state, action, reward, done, next_state))

    # Create model
    def build_model(self):
        model = keras.Sequential()
        model.add(keras.layers.Dense(64, input_shape=(self.action_space,), activation='relu'))
        model.add(keras.layers.Dense(64, activation='relu'))
        model.add(keras.layers.Dense(self.action_space, activation='linear'))
        model.compile(loss='mse', optimizer=keras.optimizers.Adam(lr=self.learning_rate), metrics=keras.metrics.top_k_categorical_accuracy)
        return model

    # Predict action from current state
    def act(self, state):
        # Epsilon greedy for exploration vs. exploitation dilemma
        exploration = (np.random.uniform(0,1) < self.epsilon)
        
        if exploration:
          action = np.random.randint(self.action_space)
        else:
          prediction = self.model.predict(state)
          action = np.argmax(prediction)

        self.action_count[action] += 1
        
        return action

    # Train Neural Network
    def train(self):
        if len(self.memory) < self.batch_size:
          return

        # Create Training Data
        
        ## Get latest episodes to generate training batch
        minibatch = list(self.memory)[-self.batch_size:] 
        states = np.array([i[0] for i in minibatch])
        actions = np.array([i[1] for i in minibatch])
        rewards = np.array([i[2] for i in minibatch])
        next_states = np.array([i[4] for i in minibatch])
        dones = np.array([i[3] for i in minibatch])

        states = np.squeeze(states)
        next_states = np.squeeze(next_states)

        # Q-Algorithm to learn
        targets = np.amax(states) - self.learning_rate * (rewards + self.discount_factor * np.amax(self.model.predict_on_batch(next_states), axis=1) - np.amax(states))
        # Old algorithm: rewards + self.learning_rate*(np.amax(self.model.predict_on_batch(next_states), axis=1))*(1-dones)
        targets_full = self.model.predict_on_batch(states)

        # Map updated q_values to action_space
        ind = np.array([i for i in range(self.batch_size)])
        targets_full[[ind], [actions]] = targets

        # Train model with state and action_space of each memorized episode in batch
        history = self.model.fit(states, targets_full, epochs=1)
        self.loss.append(history.history['loss'][0])
        self.acc.append(history.history['top_k_categorical_accuracy'][0])

# %% [markdown]
# ### 3.3 Run Reinforcement Learning System

# %%
action_space = 18
state_space = 18
user_index = 0

genreRewards = []


# Initialize Environment & Agent
env = Environment(user_index, action_space)
agent = Agent(action_space, userSequencePool[user_index])

for currentRating in range(len(userSequencePool[user_index])):
  isDone = True if currentRating == len(userSequencePool[user_index]) - 1 else False

# # Act
  ## Predict next possible user action
  action = agent.act(np.reshape(env.state, (1, state_space)))
  ## Observe action and generate reward
  reward, currentUser = env.episode(currentRating, action)
  genreRewards.append([action, reward])

# # Update environment
  ## Save current state
  state = env.state
  ## Update the environment with current reward
  env.update_state(currentUser[0], reward)
  ## Save next_state
  next_state = env.state

# # Remember this episode
  agent.remember(reward, action, state, next_state, isDone)

# # Train the neural network
  agent.train()
# Out:
# 1/1 [==============================] - 0s 321ms/step - loss: 0.1706 - top_k_categorical_accuracy: 0.9062
# 1/1 [==============================] - 0s 5ms/step - loss: 17.3018 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0545 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 4ms/step - loss: 0.5181 - top_k_categorical_accuracy: 0.0938
# 1/1 [==============================] - 0s 3ms/step - loss: 0.3324 - top_k_categorical_accuracy: 0.8438
# 1/1 [==============================] - 0s 4ms/step - loss: 0.1389 - top_k_categorical_accuracy: 0.8750
# 1/1 [==============================] - 0s 7ms/step - loss: 0.0720 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 3ms/step - loss: 0.0860 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 6ms/step - loss: 0.0147 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 3ms/step - loss: 0.0384 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 3ms/step - loss: 0.0362 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0289 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 3ms/step - loss: 0.0416 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0229 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0048 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 3ms/step - loss: 0.0232 - top_k_categorical_accuracy: 0.9062
# 1/1 [==============================] - 0s 3ms/step - loss: 0.0444 - top_k_categorical_accuracy: 0.7812
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0267 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 3ms/step - loss: 0.0260 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 3ms/step - loss: 0.0077 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 6ms/step - loss: 0.0114 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0102 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 5ms/step - loss: 0.0097 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 6ms/step - loss: 0.0157 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 3ms/step - loss: 0.0067 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0047 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0040 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 3ms/step - loss: 0.0035 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0058 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0058 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 5ms/step - loss: 0.0045 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 5ms/step - loss: 0.0030 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0223 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0163 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0117 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0279 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0191 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0132 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 3ms/step - loss: 0.0070 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 6ms/step - loss: 0.0080 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0264 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0404 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 3ms/step - loss: 0.0324 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0219 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 3ms/step - loss: 0.0196 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0141 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0112 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0101 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0096 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0174 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 5ms/step - loss: 0.0165 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0180 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 3ms/step - loss: 0.0163 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0105 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 3ms/step - loss: 0.0076 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0190 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 5ms/step - loss: 0.0225 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0172 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0157 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 5ms/step - loss: 0.0095 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 3ms/step - loss: 0.0063 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 7ms/step - loss: 0.0036 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0035 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0097 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 3ms/step - loss: 0.0105 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0128 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 3ms/step - loss: 0.0279 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0202 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0155 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0085 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0062 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0052 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0052 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 3ms/step - loss: 0.0080 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 3ms/step - loss: 0.0086 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 5ms/step - loss: 0.0089 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0441 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0241 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 5ms/step - loss: 0.0237 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0136 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 3ms/step - loss: 0.0059 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0113 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 5ms/step - loss: 0.0117 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0099 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0115 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 3ms/step - loss: 0.0141 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 3ms/step - loss: 0.0104 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0129 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 5ms/step - loss: 0.0128 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0132 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0120 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 3ms/step - loss: 0.0071 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0030 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0050 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 3ms/step - loss: 0.0058 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0043 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 5ms/step - loss: 0.0037 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0031 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0026 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0030 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0033 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0023 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0017 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 6ms/step - loss: 0.0024 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0023 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 3ms/step - loss: 0.0026 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 7ms/step - loss: 0.0024 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 4ms/step - loss: 8.8431e-04 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 3ms/step - loss: 7.6327e-04 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0013 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 3ms/step - loss: 0.0014 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0015 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 3ms/step - loss: 9.6785e-04 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 3ms/step - loss: 6.6017e-04 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 4ms/step - loss: 9.0844e-04 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0010 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 4ms/step - loss: 9.9412e-04 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 4ms/step - loss: 8.1184e-04 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 6ms/step - loss: 5.6026e-04 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 4ms/step - loss: 5.8890e-04 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 4ms/step - loss: 7.7097e-04 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 4ms/step - loss: 6.9984e-04 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 5ms/step - loss: 4.5160e-04 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 4ms/step - loss: 2.6479e-04 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 3ms/step - loss: 3.0929e-04 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 5ms/step - loss: 5.0560e-04 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 4ms/step - loss: 4.7078e-04 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 3ms/step - loss: 3.2880e-04 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 7ms/step - loss: 1.1873e-04 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 7ms/step - loss: 6.3637e-05 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 4ms/step - loss: 1.9889e-04 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 4ms/step - loss: 4.3648e-04 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 3ms/step - loss: 3.9535e-04 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 3ms/step - loss: 0.0200 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0147 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 7ms/step - loss: 0.0093 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0045 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0024 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 4ms/step - loss: 5.0905e-04 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0034 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 7ms/step - loss: 0.0075 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 3ms/step - loss: 0.0089 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0217 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0137 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0064 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0053 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0052 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0043 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 5ms/step - loss: 0.0048 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0055 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0077 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 5ms/step - loss: 0.0063 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0048 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0026 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0024 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0128 - top_k_categorical_accuracy: 0.8125
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0047 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0070 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0100 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0045 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0021 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 5ms/step - loss: 0.0042 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0042 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0026 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0022 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0023 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0018 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 6ms/step - loss: 0.0025 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 5ms/step - loss: 0.0019 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0017 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 4ms/step - loss: 8.8413e-04 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 3ms/step - loss: 0.0010 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0163 - top_k_categorical_accuracy: 0.5625
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0093 - top_k_categorical_accuracy: 0.9688
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0058 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0107 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0101 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0046 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0040 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0071 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0079 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 3ms/step - loss: 0.0054 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0021 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 3ms/step - loss: 0.0020 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 3ms/step - loss: 0.0038 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0050 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 3ms/step - loss: 0.0036 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0022 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0019 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0022 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0021 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0015 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 5ms/step - loss: 0.0015 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0015 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0014 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 4ms/step - loss: 9.1921e-04 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 3ms/step - loss: 9.0104e-04 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 3ms/step - loss: 0.0011 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0011 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0011 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 5ms/step - loss: 9.0590e-04 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 4ms/step - loss: 9.0751e-04 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 4ms/step - loss: 9.0424e-04 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 4ms/step - loss: 7.3649e-04 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 5ms/step - loss: 3.6281e-04 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 4ms/step - loss: 4.1188e-04 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 8ms/step - loss: 4.8396e-04 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 4ms/step - loss: 6.0322e-04 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 4ms/step - loss: 5.4602e-04 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 11ms/step - loss: 3.7220e-04 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 4ms/step - loss: 2.5905e-04 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 5ms/step - loss: 5.3500e-04 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 3ms/step - loss: 5.9590e-04 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 4ms/step - loss: 3.4483e-04 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 4ms/step - loss: 2.2204e-04 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 7ms/step - loss: 1.4110e-04 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 5ms/step - loss: 3.0361e-04 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 5ms/step - loss: 2.3600e-04 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 4ms/step - loss: 1.4846e-04 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 4ms/step - loss: 1.2765e-04 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 3ms/step - loss: 1.5038e-04 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 3ms/step - loss: 2.2932e-04 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 4ms/step - loss: 2.4789e-04 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 4ms/step - loss: 6.2402e-05 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 4ms/step - loss: 1.0681e-04 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 4ms/step - loss: 2.7406e-04 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 4ms/step - loss: 3.1139e-04 - top_k_categorical_accuracy: 0.4688
# 1/1 [==============================] - 0s 4ms/step - loss: 1.9271e-04 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 8ms/step - loss: 1.1079e-04 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 4ms/step - loss: 2.3292e-04 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 3ms/step - loss: 4.3745e-04 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 7ms/step - loss: 3.2304e-04 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 4ms/step - loss: 2.1023e-04 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 3ms/step - loss: 2.8542e-04 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 3ms/step - loss: 2.8979e-04 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 3ms/step - loss: 4.8475e-04 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 12ms/step - loss: 3.8296e-04 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 19ms/step - loss: 2.0917e-04 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 5ms/step - loss: 9.4553e-05 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 5ms/step - loss: 1.0088e-04 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 4ms/step - loss: 2.8817e-04 - top_k_categorical_accuracy: 0.3438
# 1/1 [==============================] - 0s 13ms/step - loss: 9.8899e-05 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 5ms/step - loss: 7.7365e-05 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 5ms/step - loss: 3.0999e-04 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 4ms/step - loss: 6.3528e-04 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 4ms/step - loss: 5.1559e-04 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 7ms/step - loss: 2.2473e-04 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 5ms/step - loss: 1.3697e-04 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 10ms/step - loss: 1.1715e-04 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 5ms/step - loss: 0.0724 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 5ms/step - loss: 0.0124 - top_k_categorical_accuracy: 0.1250
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0237 - top_k_categorical_accuracy: 0.1250
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0214 - top_k_categorical_accuracy: 0.1562
# 1/1 [==============================] - 0s 3ms/step - loss: 0.0112 - top_k_categorical_accuracy: 0.1562
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0020 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 3ms/step - loss: 0.0033 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 5ms/step - loss: 0.0069 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0082 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0043 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0013 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 5ms/step - loss: 5.3373e-04 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0017 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0026 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0031 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0023 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 4ms/step - loss: 8.8858e-04 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 5ms/step - loss: 4.5264e-04 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 4ms/step - loss: 8.0451e-04 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 6ms/step - loss: 0.0013 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0012 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 5ms/step - loss: 8.0746e-04 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 4ms/step - loss: 4.0137e-04 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 4ms/step - loss: 3.6893e-04 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 4ms/step - loss: 6.1243e-04 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 4ms/step - loss: 9.1911e-04 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 4ms/step - loss: 7.0198e-04 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0012 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0010 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0012 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 3ms/step - loss: 0.0011 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 6ms/step - loss: 0.0010 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 4ms/step - loss: 8.2764e-04 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 4ms/step - loss: 6.1526e-04 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 4ms/step - loss: 5.1586e-04 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0085 - top_k_categorical_accuracy: 0.2500
# 1/1 [==============================] - 0s 6ms/step - loss: 0.0056 - top_k_categorical_accuracy: 0.4062
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0161 - top_k_categorical_accuracy: 0.4062
# 1/1 [==============================] - 0s 3ms/step - loss: 0.0059 - top_k_categorical_accuracy: 0.4688
# 1/1 [==============================] - 0s 4ms/step - loss: 9.8545e-04 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 7ms/step - loss: 0.0056 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0118 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0113 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 4ms/step - loss: 9.4273e-04 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0026 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0039 - top_k_categorical_accuracy: 0.3438
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0024 - top_k_categorical_accuracy: 0.3750
# 1/1 [==============================] - 0s 4ms/step - loss: 9.1602e-04 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 11ms/step - loss: 1.6768e-04 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 3ms/step - loss: 6.5251e-04 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0016 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0015 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 5ms/step - loss: 6.2493e-04 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 5ms/step - loss: 5.4354e-04 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 5ms/step - loss: 0.0010 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0013 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 7ms/step - loss: 5.9591e-04 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 4ms/step - loss: 2.0955e-04 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 5ms/step - loss: 4.6298e-04 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 7ms/step - loss: 7.3616e-04 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 4ms/step - loss: 5.6344e-04 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 4ms/step - loss: 2.2850e-04 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 4ms/step - loss: 1.9506e-04 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 4ms/step - loss: 3.6644e-04 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 4ms/step - loss: 4.7048e-04 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 5ms/step - loss: 3.5284e-04 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 4ms/step - loss: 1.6996e-04 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 3ms/step - loss: 1.4611e-04 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 4ms/step - loss: 4.0868e-04 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 4ms/step - loss: 3.7237e-04 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 4ms/step - loss: 1.4657e-04 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 4ms/step - loss: 5.1075e-05 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 4ms/step - loss: 9.9890e-05 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 4ms/step - loss: 2.1026e-04 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 5ms/step - loss: 1.9364e-04 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 4ms/step - loss: 1.4809e-04 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 42ms/step - loss: 7.1463e-05 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 8ms/step - loss: 4.6926e-05 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 4ms/step - loss: 7.9142e-05 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0417 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 5ms/step - loss: 0.0035 - top_k_categorical_accuracy: 0.1562
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0092 - top_k_categorical_accuracy: 0.1875
# 1/1 [==============================] - 0s 7ms/step - loss: 0.0108 - top_k_categorical_accuracy: 0.1875
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0077 - top_k_categorical_accuracy: 0.2188
# 1/1 [==============================] - 0s 6ms/step - loss: 0.0026 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 4ms/step - loss: 8.4717e-04 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0023 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0044 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0038 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0018 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0015 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0028 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0034 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0022 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 4ms/step - loss: 6.1764e-04 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 5ms/step - loss: 2.3467e-04 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0013 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0024 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0018 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 4ms/step - loss: 4.2155e-04 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 5ms/step - loss: 2.6096e-04 - top_k_categorical_accuracy: 0.5000
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0011 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0015 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 4ms/step - loss: 7.9001e-04 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 4ms/step - loss: 2.0817e-04 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 4ms/step - loss: 3.5688e-04 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 4ms/step - loss: 6.9381e-04 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 7ms/step - loss: 6.6336e-04 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 4ms/step - loss: 5.9777e-04 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 4ms/step - loss: 2.7387e-04 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 4ms/step - loss: 3.3871e-04 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 4ms/step - loss: 2.7696e-04 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 4ms/step - loss: 3.1422e-04 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 7ms/step - loss: 2.5185e-04 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 4ms/step - loss: 2.6183e-04 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 4ms/step - loss: 2.6153e-04 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 4ms/step - loss: 3.3219e-04 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 4ms/step - loss: 2.8556e-04 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 4ms/step - loss: 3.3477e-04 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 15ms/step - loss: 4.8918e-04 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 5ms/step - loss: 2.5719e-04 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 4ms/step - loss: 1.3813e-04 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 3ms/step - loss: 1.6411e-04 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 4ms/step - loss: 2.7911e-04 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 4ms/step - loss: 1.6849e-04 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 7ms/step - loss: 1.5524e-04 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 6ms/step - loss: 2.1003e-04 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 3ms/step - loss: 2.1915e-04 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 4ms/step - loss: 1.9547e-04 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 4ms/step - loss: 1.7847e-04 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 4ms/step - loss: 1.6505e-04 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 7ms/step - loss: 1.2354e-04 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 4ms/step - loss: 1.2090e-04 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 5ms/step - loss: 1.4129e-04 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 4ms/step - loss: 1.8850e-04 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 4ms/step - loss: 1.5771e-04 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 3ms/step - loss: 1.6057e-04 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0056 - top_k_categorical_accuracy: 0.3125
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0034 - top_k_categorical_accuracy: 0.4375
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0011 - top_k_categorical_accuracy: 0.6562
# 1/1 [==============================] - 0s 4ms/step - loss: 7.8774e-04 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 5ms/step - loss: 0.0023 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0026 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0017 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 3ms/step - loss: 0.0013 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0018 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0021 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0012 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 4ms/step - loss: 5.1089e-04 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 4ms/step - loss: 7.5006e-04 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0012 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 3ms/step - loss: 0.0010 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 5ms/step - loss: 7.3665e-04 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0091 - top_k_categorical_accuracy: 0.2500
# 1/1 [==============================] - 0s 4ms/step - loss: 0.1654 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0607 - top_k_categorical_accuracy: 0.1562
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0861 - top_k_categorical_accuracy: 0.1875
# 1/1 [==============================] - 0s 4ms/step - loss: 0.1216 - top_k_categorical_accuracy: 0.3125
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0717 - top_k_categorical_accuracy: 0.2812
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0202 - top_k_categorical_accuracy: 0.3750
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0057 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0287 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0404 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0298 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 7ms/step - loss: 0.0218 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0173 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0107 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0084 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0154 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0201 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0158 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0108 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0232 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 7ms/step - loss: 0.0200 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0128 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0087 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0104 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0116 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 3ms/step - loss: 0.0092 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 3ms/step - loss: 0.0191 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0191 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0158 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 5ms/step - loss: 0.0091 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0045 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0059 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0089 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0113 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0147 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 3ms/step - loss: 0.0089 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0053 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0032 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0037 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 5ms/step - loss: 0.0062 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0067 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0058 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0040 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 3ms/step - loss: 0.0032 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0035 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0041 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0038 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 3ms/step - loss: 0.0024 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 5ms/step - loss: 0.0011 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 3ms/step - loss: 0.0024 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 3ms/step - loss: 0.0032 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 3ms/step - loss: 0.0040 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0045 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 7ms/step - loss: 0.0040 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 3ms/step - loss: 0.0025 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 3ms/step - loss: 0.0016 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 7ms/step - loss: 0.0015 - top_k_categorical_accuracy: 1.0000
# ...
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0056 - top_k_categorical_accuracy: 0.2188
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0029 - top_k_categorical_accuracy: 0.2188
# 1/1 [==============================] - 0s 4ms/step - loss: 7.3340e-04 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 3ms/step - loss: 9.3953e-04 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 3ms/step - loss: 0.0023 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 3ms/step - loss: 0.0029 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 5ms/step - loss: 0.0025 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 3ms/step - loss: 0.0014 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0011 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 5ms/step - loss: 0.0014 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 3ms/step - loss: 0.0013 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 3ms/step - loss: 0.0010 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 3ms/step - loss: 7.5431e-04 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 4ms/step - loss: 7.0000e-04 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 6ms/step - loss: 9.2765e-04 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0014 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0013 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 3ms/step - loss: 5.6241e-04 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 3ms/step - loss: 5.0667e-04 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 3ms/step - loss: 9.2479e-04 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 3ms/step - loss: 0.0012 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 3ms/step - loss: 7.7205e-04 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 4ms/step - loss: 3.7321e-04 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 4ms/step - loss: 3.4307e-04 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 9ms/step - loss: 5.9634e-04 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 4ms/step - loss: 5.0138e-04 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 7ms/step - loss: 2.3656e-04 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 4ms/step - loss: 3.3765e-04 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 4ms/step - loss: 5.0428e-04 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 12ms/step - loss: 2.4457e-04 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 4ms/step - loss: 9.9084e-05 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 4ms/step - loss: 2.1999e-04 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 4ms/step - loss: 4.0069e-04 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 4ms/step - loss: 2.8005e-04 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 7ms/step - loss: 1.1940e-04 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 7ms/step - loss: 8.0352e-05 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 7ms/step - loss: 1.6509e-04 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 8ms/step - loss: 2.2516e-04 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 7ms/step - loss: 1.7406e-04 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 4ms/step - loss: 1.0575e-04 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 4ms/step - loss: 9.2387e-05 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 9ms/step - loss: 1.6949e-04 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 7ms/step - loss: 2.2732e-04 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 4ms/step - loss: 9.5816e-05 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 4ms/step - loss: 1.2625e-04 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 4ms/step - loss: 1.9935e-04 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 4ms/step - loss: 1.8329e-04 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 3ms/step - loss: 5.7382e-05 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 4ms/step - loss: 5.9861e-05 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 4ms/step - loss: 1.6863e-04 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 11ms/step - loss: 1.4460e-04 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 7ms/step - loss: 6.1408e-05 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 3ms/step - loss: 4.6623e-05 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0065 - top_k_categorical_accuracy: 0.2812
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0015 - top_k_categorical_accuracy: 0.7812
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0025 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0038 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 3ms/step - loss: 0.0019 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0014 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0031 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0019 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 3ms/step - loss: 5.5678e-04 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 3ms/step - loss: 0.0015 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0022 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 4ms/step - loss: 8.1313e-04 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 4ms/step - loss: 3.9784e-04 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 15ms/step - loss: 0.0011 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0011 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 7ms/step - loss: 3.8245e-04 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 3ms/step - loss: 4.6572e-04 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 3ms/step - loss: 8.7697e-04 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 4ms/step - loss: 5.4883e-04 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 7ms/step - loss: 4.1696e-04 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 4ms/step - loss: 7.5703e-04 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 3ms/step - loss: 8.9042e-04 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 5ms/step - loss: 4.5497e-04 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 9ms/step - loss: 9.5601e-05 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 4ms/step - loss: 1.8287e-04 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 5ms/step - loss: 6.7678e-04 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 5ms/step - loss: 6.3713e-04 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 4ms/step - loss: 2.6877e-04 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 3ms/step - loss: 1.3225e-04 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 4ms/step - loss: 2.2604e-04 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 4ms/step - loss: 4.0347e-04 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 4ms/step - loss: 3.8186e-04 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 7ms/step - loss: 2.3661e-04 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 4ms/step - loss: 3.2392e-04 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 4ms/step - loss: 1.7694e-04 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 4ms/step - loss: 1.6088e-04 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 10ms/step - loss: 0.0013 - top_k_categorical_accuracy: 0.4375
# 1/1 [==============================] - 0s 3ms/step - loss: 4.6800e-04 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 3ms/step - loss: 1.1079e-04 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 4ms/step - loss: 6.0510e-04 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 4ms/step - loss: 7.1225e-04 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 4ms/step - loss: 1.5165e-04 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 4ms/step - loss: 1.0656e-04 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 4ms/step - loss: 3.1572e-04 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 3ms/step - loss: 2.7162e-04 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 5ms/step - loss: 1.7230e-04 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 3ms/step - loss: 1.6090e-04 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 4ms/step - loss: 2.4693e-04 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 4ms/step - loss: 1.9065e-04 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 3ms/step - loss: 8.0880e-05 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 7ms/step - loss: 7.7582e-05 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 4ms/step - loss: 1.1870e-04 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 5ms/step - loss: 1.2120e-04 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 5ms/step - loss: 7.7288e-05 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 4ms/step - loss: 7.5412e-05 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 4ms/step - loss: 9.9337e-05 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 10ms/step - loss: 9.2236e-05 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 3ms/step - loss: 5.7520e-05 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 5ms/step - loss: 3.6546e-05 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 4ms/step - loss: 8.4412e-04 - top_k_categorical_accuracy: 0.3438
# 1/1 [==============================] - 0s 4ms/step - loss: 4.1391e-04 - top_k_categorical_accuracy: 0.5938
# 1/1 [==============================] - 0s 3ms/step - loss: 1.0225e-04 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 4ms/step - loss: 3.5348e-04 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 4ms/step - loss: 3.8315e-04 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 8ms/step - loss: 2.3852e-04 - top_k_categorical_accuracy: 0.6562
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0015 - top_k_categorical_accuracy: 0.5000
# 1/1 [==============================] - 0s 4ms/step - loss: 5.8611e-04 - top_k_categorical_accuracy: 0.5938
# 1/1 [==============================] - 0s 4ms/step - loss: 1.6487e-04 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 3ms/step - loss: 0.0011 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0017 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 3ms/step - loss: 7.7335e-04 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 5ms/step - loss: 2.8542e-04 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 7ms/step - loss: 3.8920e-04 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 4ms/step - loss: 8.4507e-04 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 3ms/step - loss: 0.0010 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 4ms/step - loss: 7.3842e-04 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 7ms/step - loss: 2.8676e-04 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 6ms/step - loss: 2.8803e-04 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 8ms/step - loss: 8.2581e-04 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 12ms/step - loss: 0.0010 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 9ms/step - loss: 4.6817e-04 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 4ms/step - loss: 1.9854e-04 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 5ms/step - loss: 3.8567e-04 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 4ms/step - loss: 6.6428e-04 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 4ms/step - loss: 4.1368e-04 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 5ms/step - loss: 2.2220e-04 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 7ms/step - loss: 1.7488e-04 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 3ms/step - loss: 2.8334e-04 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 4ms/step - loss: 3.2822e-04 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 3ms/step - loss: 1.6543e-04 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 4ms/step - loss: 3.0933e-05 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 4ms/step - loss: 1.4701e-04 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 7ms/step - loss: 1.6047e-04 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 8ms/step - loss: 1.4463e-04 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 6ms/step - loss: 7.2412e-05 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 32ms/step - loss: 8.2876e-05 - top_k_categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 7ms/step - loss: 1.2397e-04 - top_k_categorical_accuracy: 1.0000

# %% [markdown]
# # 4. Visualize Results

# %% [markdown]
# #### 4.1 Comparison of actual vs maximum rewards.

# %%
def sortGenresByMean(meanValues):
  return np.array(meanValues).argsort()[-len(meanValues):][::-1]

# %%
# Maximum rewards per genre
maximumRewardsSum = np.zeros(18)
for rating in userSequencePool[user_index]:
  for i, genre in enumerate(allGenres):
      if genre in rating[0]:
        if rating[1] == 2:
          maximumRewardsSum[i] += 0.3

        if rating[1] == 1:
          maximumRewardsSum[i] -= 0.2
        
        if rating[1] == 0:
          maximumRewardsSum[i] += 0.1

# Actual rewards per genre
actualRewardsSum = np.zeros(18)
rewardsOverTime = []
for pair in genreRewards:
  rewardsOverTime.append(pair[1])
  actualRewardsSum[pair[0]] += pair[1]

# Plot
groupedData = pd.DataFrame(np.c_[maximumRewardsSum, actualRewardsSum], index=allGenres)
ax = groupedData.plot.bar(
    figsize=(20,10), 
    xlabel="Genres",
    ylabel="Total Reward Amount",
    title="Comparing actual with maximum rewards"
)
ax.legend(["Maximum rewards", "Actual rewards"]);

# %%
print('\n\nMaximum Ranking:\n')
sortedGenreByMaximumReward = sortGenresByMean(maximumRewardsSum)
for i, genreIndex in enumerate(sortedGenreByMaximumReward):
  print('%s: %s' % (i +1, allGenres[genreIndex]))
# Out:
# Maximum Ranking:
#
# 1: Action
# 2: Drama
# 3: Thriller
# 4: Sci-Fi
# 5: Adventure
# 6: Crime
# 7: Comedy
# 8: Fantasy
# 9: Mystery
# 10: Animation
# 11: Romance
# 12: Children
# 13: Horror
# 14: War
# 15: Western
# 16: Film-Noir
# 17: Musical
# 18: Documentary

# %%
print('\n\nActual Ranking:\n')
sortedGenreByActualReward = sortGenresByMean(actualRewardsSum)
for i, genreIndex in enumerate(sortedGenreByActualReward):
  print('%s: %s' % (i +1, allGenres[genreIndex]))
# Out:
# Actual Ranking:
#
# 1: Action
# 2: Drama
# 3: Crime
# 4: Adventure
# 5: Sci-Fi
# 6: Thriller
# 7: Mystery
# 8: Comedy
# 9: Horror
# 10: Romance
# 11: Musical
# 12: Fantasy
# 13: Film-Noir
# 14: War
# 15: Children
# 16: Animation
# 17: Documentary
# 18: Western

# %%
def mapRatingsToEpisodes(ratings):
  for genreIndex, array in enumerate(ratings):
    arraySteps = list(range(0, len(genreRewards)))
    currentGenreDevelopment = np.zeros(len(genreRewards))
    increment = 0
    for j, value in enumerate(currentGenreDevelopment):
      for val in array:
        if val[0] == j:
          increment = val[1]
      currentGenreDevelopment[j] = increment
    ratings[genreIndex] = currentGenreDevelopment
  return ratings  

def createGenreMeanValues(ratingsPerGenre, step):
  allGenreMeanValues = [[] for i in allGenres]
  for genreIndex, genre in enumerate(ratingsPerGenre):
    genreMeanValues = []
    for episodeIndex, episode in enumerate(genre):
      snapshot = episodeIndex + 1
      if snapshot % step == 0:
        genreMeanValues.append(np.mean(genre[:episodeIndex]))
    allGenreMeanValues[genreIndex].append(genreMeanValues) 
  return allGenreMeanValues


def sumMeanValuesPerStep(rewards):
  sumMeanValuesPerSnapshot = [[] for snapshot in range(0, snapshots)]
  for snapshotIndex, snapshot in enumerate(range(0, snapshots)):
    for genreIndex, genre in enumerate(allGenres):
      sumMeanValuesPerSnapshot[snapshotIndex].append(rewards[genreIndex][0][snapshotIndex])
  return [np.mean(item) for item in sumMeanValuesPerSnapshot]


actualRewards = [[] for i in allGenres]
maximumRewards = [[] for i in allGenres]
snapshots = 9
dataStep = math.floor(len(userSequencePool[user_index]) / snapshots)

# Maximum rewards per genre
for ratingIndex, rating in enumerate(userSequencePool[user_index]):
  for genreIndex, genre in enumerate(allGenres):
      if genre in rating[0]:
        if rating[1] == 2:
          maximumRewards[genreIndex].append([ratingIndex, 0.3])

        if rating[1] == 1:
          maximumRewards[genreIndex].append([ratingIndex, -0.2])
        
        if rating[1] == 0:
          maximumRewards[genreIndex].append([ratingIndex, 0.1])

# Actual rewards per genre
for i, pair in enumerate(genreRewards):
  actualRewards[pair[0]].append([i, pair[1]])

maximumRewards = mapRatingsToEpisodes(maximumRewards)
actualRewards = mapRatingsToEpisodes(actualRewards)

maximumRewards = createGenreMeanValues(maximumRewards, dataStep)
actualRewards = createGenreMeanValues(actualRewards, dataStep)

maximumRewards = sumMeanValuesPerStep(maximumRewards)
actualRewards = sumMeanValuesPerStep(actualRewards)

x = np.arange(np.array(snapshots))
width = 0.3
plt.figure(figsize=(20,10))
plt.xlabel("Snapshots")
plt.ylabel("Reward")
plt.title("Maximum vs. Actual Mean")

plt.bar(x - width/2 + 1, np.array(maximumRewards), width=width, label="Maximum")
plt.bar(x + width/2 + 1, np.array(actualRewards), width=width, label="Actual")

plt.legend()
plt.show()

# %% [markdown]
# #### 4.2 Genre reward sum per episode

# %%
numColors = len(allGenres)
cm = plt.get_cmap('tab20c')
genreChange = [[] for i in allGenres]
for ratingIndex, genreRewardPair in enumerate(genreRewards):
  genreChange[genreRewardPair[0]].append([ratingIndex, genreRewardPair[1]])

fig = plt.figure(figsize=(20,10))
ax = fig.add_subplot(111)
plt.xlabel("User Rating")
plt.ylabel("Reward")
plt.title("Change of genre predictions over episodes")
ax.set_prop_cycle('color', [cm(1.*i/numColors) for i in range(numColors)])

for genre, array in enumerate(genreChange):
  arraySteps = list(range(0, len(genreRewards)))
  currentGenreChange = np.zeros(len(genreRewards))
  increment = 0
  for j, value in enumerate(currentGenreChange):
    for val in array:
      if val[0] == j:
        increment += val[1]
    currentGenreChange[j] = increment
  ax.plot(arraySteps, currentGenreChange, label=allGenres[genre])
ax.legend()

# %%
numColors = len(allGenres)
cm = plt.get_cmap('tab20c')
genreChange = [[] for i in allGenres]
for ratingIndex, rating in enumerate(userSequencePool[user_index]):
  for genreIndex, genre in enumerate(allGenres):
      if genre in rating[0]:
        if rating[1] == 2:
          genreChange[genreIndex].append([ratingIndex, 0.3])

        if rating[1] == 1:
          genreChange[genreIndex].append([ratingIndex, -0.2])
        
        if rating[1] == 0:
          genreChange[genreIndex].append([ratingIndex, 0.1])

fig = plt.figure(figsize=(20,10))
ax = fig.add_subplot(111)
plt.xlabel("User Rating")
plt.ylabel("Reward")
plt.title("Change of genre maximum over episodes")
ax.set_prop_cycle('color', [cm(1.*i/numColors) for i in range(numColors)])

for genre, array in enumerate(genreChange):
  arraySteps = list(range(0, len(genreRewards)))
  currentGenreChange = np.zeros(len(genreRewards))
  increment = 0
  for j, value in enumerate(currentGenreChange):
    for val in array:
      if val[0] == j:
        increment += val[1]
    currentGenreChange[j] = increment
  ax.plot(arraySteps, currentGenreChange, label=allGenres[genre])
ax.legend()

# %%
def getPositiveValues(val):
  return (-1) * val

numColors = len(allGenres)
cm = plt.get_cmap('tab20c')
genresStacked = []
genreDevelopment = [[] for i in allGenres]
genresStackedNormalized = [[] for i in allGenres]
episodeMins = list(np.zeros(len(genreRewards)))

for i, pair in enumerate(genreRewards):
  genreDevelopment[pair[0]].append([i, pair[1]])

for genre, array in enumerate(genreDevelopment):
  increment = 0
  currentGenreDevelopment = np.zeros(len(genreRewards))
  for j, value in enumerate(currentGenreDevelopment):
    for val in array:
      if val[0] == j:
        increment += val[1]
    currentGenreDevelopment[j] = increment
  genresStacked.append(currentGenreDevelopment)

  for e, episodeValue in enumerate(genresStacked[genre]):
    if episodeValue < episodeMins[e]:
      episodeMins[e] = episodeValue

for episodeMinInd, episodeMin in enumerate(episodeMins):
  episodeMins[episodeMinInd] = getPositiveValues(episodeMin)


for genreInd, genreArray in enumerate(genresStacked):
  for episodeInd, episodeValue in enumerate(genreArray):
    genresStackedNormalized[genreInd].append(episodeValue + episodeMins[episodeInd])
genresStacked = genresStackedNormalized

width = 1
fig = plt.figure(figsize=(30,10))
ax = fig.add_subplot(111)
ax.set_prop_cycle('color', [cm(1.*i/numColors) for i in range(numColors)])

p1 = plt.bar(list(range(0, len(genreRewards))), np.array(genresStacked[0]), width)
p2 = plt.bar(list(range(0, len(genreRewards))), np.array(genresStacked[1]), width, bottom=np.array(genresStacked[0]))
p3 = plt.bar(list(range(0, len(genreRewards))), np.array(genresStacked[2]), width, bottom=np.array(genresStacked[0]) + np.array(genresStacked[1]))
p4 = plt.bar(list(range(0, len(genreRewards))), np.array(genresStacked[3]), width, bottom=np.array(genresStacked[0]) + np.array(genresStacked[1]) + np.array(genresStacked[2]))
p5 = plt.bar(list(range(0, len(genreRewards))), np.array(genresStacked[4]), width, bottom=np.array(genresStacked[0]) + np.array(genresStacked[1]) + np.array(genresStacked[2]) + np.array(genresStacked[3]))
p6 = plt.bar(list(range(0, len(genreRewards))), np.array(genresStacked[5]), width, bottom=np.array(genresStacked[0]) + np.array(genresStacked[1]) + np.array(genresStacked[2]) + np.array(genresStacked[3]) + np.array(genresStacked[4]))
p7 = plt.bar(list(range(0, len(genreRewards))), np.array(genresStacked[6]), width, bottom=np.array(genresStacked[0]) + np.array(genresStacked[1]) + np.array(genresStacked[2]) + np.array(genresStacked[3]) + np.array(genresStacked[4]) + np.array(genresStacked[5]))
p8 = plt.bar(list(range(0, len(genreRewards))), np.array(genresStacked[7]), width, bottom=np.array(genresStacked[0]) + np.array(genresStacked[1]) + np.array(genresStacked[2]) + np.array(genresStacked[3]) + np.array(genresStacked[4]) + np.array(genresStacked[5]) + np.array(genresStacked[6]))
p9 = plt.bar(list(range(0, len(genreRewards))), np.array(genresStacked[8]), width, bottom=np.array(genresStacked[0]) + np.array(genresStacked[1]) + np.array(genresStacked[2]) + np.array(genresStacked[3]) + np.array(genresStacked[4]) + np.array(genresStacked[5]) + np.array(genresStacked[6]) + np.array(genresStacked[7]))
p10 = plt.bar(list(range(0, len(genreRewards))), np.array(genresStacked[9]), width, bottom=np.array(genresStacked[0]) + np.array(genresStacked[1]) + np.array(genresStacked[2]) + np.array(genresStacked[3]) + np.array(genresStacked[4]) + np.array(genresStacked[5]) + np.array(genresStacked[6]) + np.array(genresStacked[7]) + np.array(genresStacked[8]))
p11 = plt.bar(list(range(0, len(genreRewards))), np.array(genresStacked[10]), width, bottom=np.array(genresStacked[0]) + np.array(genresStacked[1]) + np.array(genresStacked[2]) + np.array(genresStacked[3]) + np.array(genresStacked[4]) + np.array(genresStacked[5]) + np.array(genresStacked[6]) + np.array(genresStacked[7]) + np.array(genresStacked[8]) + np.array(genresStacked[9]))
p12 = plt.bar(list(range(0, len(genreRewards))), np.array(genresStacked[11]), width, bottom=np.array(genresStacked[0]) + np.array(genresStacked[1]) + np.array(genresStacked[2]) + np.array(genresStacked[3]) + np.array(genresStacked[4]) + np.array(genresStacked[5]) + np.array(genresStacked[6]) + np.array(genresStacked[7]) + np.array(genresStacked[8]) + np.array(genresStacked[9]) + np.array(genresStacked[10]))
p13 = plt.bar(list(range(0, len(genreRewards))), np.array(genresStacked[12]), width, bottom=np.array(genresStacked[0]) + np.array(genresStacked[1]) + np.array(genresStacked[2]) + np.array(genresStacked[3]) + np.array(genresStacked[4]) + np.array(genresStacked[5]) + np.array(genresStacked[6]) + np.array(genresStacked[7]) + np.array(genresStacked[8]) + np.array(genresStacked[9]) + np.array(genresStacked[10]) + np.array(genresStacked[11]))
p14 = plt.bar(list(range(0, len(genreRewards))), np.array(genresStacked[13]), width, bottom=np.array(genresStacked[0]) + np.array(genresStacked[1]) + np.array(genresStacked[2]) + np.array(genresStacked[3]) + np.array(genresStacked[4]) + np.array(genresStacked[5]) + np.array(genresStacked[6]) + np.array(genresStacked[7]) + np.array(genresStacked[8]) + np.array(genresStacked[9]) + np.array(genresStacked[10]) + np.array(genresStacked[11]) + np.array(genresStacked[12]))
p15 = plt.bar(list(range(0, len(genreRewards))), np.array(genresStacked[14]), width, bottom=np.array(genresStacked[0]) + np.array(genresStacked[1]) + np.array(genresStacked[2]) + np.array(genresStacked[3]) + np.array(genresStacked[4]) + np.array(genresStacked[5]) + np.array(genresStacked[6]) + np.array(genresStacked[7]) + np.array(genresStacked[8]) + np.array(genresStacked[9]) + np.array(genresStacked[10]) + np.array(genresStacked[11]) + np.array(genresStacked[12]) + np.array(genresStacked[13]))
p16 = plt.bar(list(range(0, len(genreRewards))), np.array(genresStacked[15]), width, bottom=np.array(genresStacked[0]) + np.array(genresStacked[1]) + np.array(genresStacked[2]) + np.array(genresStacked[3]) + np.array(genresStacked[4]) + np.array(genresStacked[5]) + np.array(genresStacked[6]) + np.array(genresStacked[7]) + np.array(genresStacked[8]) + np.array(genresStacked[9]) + np.array(genresStacked[10]) + np.array(genresStacked[11]) + np.array(genresStacked[12]) + np.array(genresStacked[13]) + np.array(genresStacked[14]))
p17 = plt.bar(list(range(0, len(genreRewards))), np.array(genresStacked[16]), width, bottom=np.array(genresStacked[0]) + np.array(genresStacked[1]) + np.array(genresStacked[2]) + np.array(genresStacked[3]) + np.array(genresStacked[4]) + np.array(genresStacked[5]) + np.array(genresStacked[6]) + np.array(genresStacked[7]) + np.array(genresStacked[8]) + np.array(genresStacked[9]) + np.array(genresStacked[10]) + np.array(genresStacked[11]) + np.array(genresStacked[12]) + np.array(genresStacked[13]) + np.array(genresStacked[14]) + np.array(genresStacked[15]))
p18 = plt.bar(list(range(0, len(genreRewards))), np.array(genresStacked[17]), width, bottom=np.array(genresStacked[0]) + np.array(genresStacked[1]) + np.array(genresStacked[2]) + np.array(genresStacked[3]) + np.array(genresStacked[4]) + np.array(genresStacked[5]) + np.array(genresStacked[6]) + np.array(genresStacked[7]) + np.array(genresStacked[8]) + np.array(genresStacked[9]) + np.array(genresStacked[10]) + np.array(genresStacked[11]) + np.array(genresStacked[12]) + np.array(genresStacked[13]) + np.array(genresStacked[14]) + np.array(genresStacked[15]) + np.array(genresStacked[16]))


plt.xlabel("User Interaction Steps")
plt.ylabel("Reward Amount")
plt.title("Comparison of genre rewards over time")
plt.legend((p1[0], p2[0], p3[0], p4[0], p5[0], p6[0], p7[0], p8[0], p9[0], p10[0], p11[0], p12[0], p13[0], p14[0], p15[0], p16[0], p17[0], p18[0]), (allGenres))
plt.show()

# %% [markdown]
# #### 4.3 Means and ranking of all data

# %%
# Recommend five random movies from recommended genre

def handleUserEpisode(numberOfRecommendations, prediction):
  recommendedGenre = allGenres[np.argmax(prediction)]
  moviesOfRecommendedGenre = movies[movies[recommendedGenre] == True]

  randomMoviesOfRecommendedGenre = random.sample(list(np.array(moviesOfRecommendedGenre['movieId'])), numberOfRecommendations)

  print('%s %s Movie Recommendations: \n' % (numberOfRecommendations, recommendedGenre))
  for id in randomMoviesOfRecommendedGenre:
    print(movies[movies['movieId'] == id]['title']) # TODO: Add genres

handleUserEpisode(5, actualRewardsSum)

# TODO:
# Connect the UI
# Out:
# 5 Action Movie Recommendations:
#
# 24790    Ice Soldiers (2013)
# Name: title, dtype: object
# 33052    Devil of the Desert Against the Son of Hercule...
# Name: title, dtype: object
# 54946    Occupation (2018)
# Name: title, dtype: object
# 8792    Last Hurrah for Chivalry (Hao xia) (1979)
# Name: title, dtype: object
# 48999    Seven Steps of Kung Fu (1979)
# Name: title, dtype: object

# %%
print("Mean of the individual genre rating:\n")

genreMeanValues = []

for genre in allGenres:
  currentMean = getGenreMean(genre)
  genreMeanValues.append(currentMean)
  print('%s: %s' % (genre, round(currentMean, 3)))

print('\n\nGlobal Ranking:\n')
sortedGenreMeanValues = sortGenresByMean(genreMeanValues)
for i, genreIndex in enumerate(sortedGenreMeanValues):
  print('%s: %s' % (i +1, allGenres[genreIndex]))
# Out:
# Mean of the individual genre rating:
#
# Adventure: 3.511
# Action: 3.463
# Animation: 3.616
# Children: 3.432
# Comedy: 3.425
# Crime: 3.691
# Documentary: 3.705
# Drama: 3.688
# Fantasy: 3.505
# Film-Noir: 3.914
# Horror: 3.284
# Musical: 3.559
# Mystery: 3.672
# Romance: 3.55
# Sci-Fi: 3.477
# Thriller: 3.525
# War: 3.799
# Western: 3.589
#
#
# Global Ranking:
#
# 1: Film-Noir
# 2: War
# 3: Documentary
# 4: Crime
# 5: Drama
# 6: Mystery
# 7: Animation
# 8: Western
# 9: Musical
# 10: Romance
# 11: Thriller
# 12: Adventure
# 13: Fantasy
# 14: Sci-Fi
# 15: Action
# 16: Children
# 17: Comedy
# 18: Horror
